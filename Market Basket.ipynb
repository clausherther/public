# %%
import os
import sys
import pandas as pd
import psycopg2
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %matplotlib inline
pylab.rcParams['figure.figsize'] = (12.0, 8.0)

# %%
CONN = os.environ.get('REDSHIFT_CONNECTION')
def query(sql):
    rs_con = psycopg2.connect(CONN)
    df = pd.read_sql(sql, con=rs_con)

    rs_con.close()

    return df

# %%
sql = """
with products as
(
    select
        p.product_id,
        p.product_set_name,
        p.product_set_category_group_name
    from
        da_dim.d_product_set p
    where p.product_set_category_group_name not in 
        ('Cufflinks & Studs', 'Accessory') and 
        p.product_set_name not in ('Cotton Dress Shirt')
)
select
    r.order_id,
    r.event_id,
    r.user_id,
    p.product_id,
    p.product_set_name as product_name,
    sum(r.checkout_item_cnt) as checkouts
from
    da_dim.f_checkouts_items r
    join
    products p on r.product_id = p.product_id
where
    r.item_is_valid = 1
    and
    r.event_date >=
        cast(date_trunc('week',
            convert_timezone('pst', getdate()) - Interval '53 Week') as date)
group by 1,2,3,4,5
order by r.order_id, p.product_id
"""

# %%
df = query(sql)

# %%
df.head()
# Out:
#    order_id  event_id  user_id  product_id             product_name  checkouts
# 0      4063      4101       81          57       Notch Lapel Tuxedo          1
# 1      4063      4101       81         229  Black Butterfly Bow Tie          1
# 2     12536     12359      270          59        Peak Lapel Tuxedo          1
# 3     12536     12359      270          73  Black Leather Wood Sole          1
# 4     12536     12359      270         229  Black Butterfly Bow Tie          1

# %%
basket = (df
          .groupby(['order_id', 'product_name'])['checkouts']
          .sum().unstack().reset_index().fillna(0)
          .set_index('order_id'))

# %%
basket.head()
# Out:
# product_name  Apricot Butterfly Bow Tie  Barre Pinstripe Tuxedo  \
# order_id
# 4063                                0.0                     0.0
# 12536                               0.0                     0.0
# 95953                               0.0                     0.0
# 434380                              0.0                     0.0
# 531208                              0.0                     0.0
#
# product_name  Black & Tartan Tuxedo  Black & White Silk Repp Bow Tie  \
# order_id
# 4063                            0.0                              0.0
# 12536                           0.0                              0.0
# 95953                           0.0                              0.0
# 434380                          0.0                              0.0
# 531208                          0.0                              0.0
#
# product_name  Black Belt  Black Butterfly Bow Tie  Black Cotton Necktie  \
# order_id
# 4063                 0.0                      1.0                   0.0
# 12536                0.0                      1.0                   0.0
# 95953                0.0                      1.0                   0.0
# 434380               0.0                      0.0                   0.0
# 531208               0.0                      0.0                   0.0
#
# product_name  Black Grosgrain Loafers  Black Holly Diamond Bow Tie  \
# order_id
# 4063                              0.0                          0.0
# 12536                             0.0                          0.0
# 95953                             0.0                          0.0
# 434380                            0.0                          0.0
# 531208                            0.0                          0.0
#
# product_name  Black Knit Bow Tie                ...                  \
# order_id                                        ...
# 4063                         0.0                ...
# 12536                        0.0                ...
# 95953                        0.0                ...
# 434380                       0.0                ...
# 531208                       0.0                ...
#
# product_name  Velvet Jacket Tuxedo  Velvet Slip-On Shoes  \
# order_id
# 4063                           0.0                   0.0
# 12536                          0.0                   0.0
# 95953                          0.0                   0.0
# 434380                         0.0                   0.0
# 531208                         0.0                   0.0
#
# product_name  Velvet Tuxedo Jacket   Violet Butterfly Bow Tie  \
# order_id
# 4063                            0.0                       0.0
# 12536                           0.0                       0.0
# 95953                           0.0                       0.0
# 434380                          0.0                       0.0
# 531208                          0.0                       0.0
#
# product_name  White Dinner Jacket Tuxedo  White Linen Necktie  \
# order_id
# 4063                                 0.0                  0.0
# 12536                                0.0                  0.0
# 95953                                0.0                  0.0
# 434380                               0.0                  0.0
# 531208                               0.0                  0.0
#
# product_name  White Linen Wide Bow Tie  White Tuxedo Jacket   \
# order_id
# 4063                               0.0                   0.0
# 12536                              0.0                   0.0
# 95953                              0.0                   0.0
# 434380                             0.0                   0.0
# 531208                             0.0                   0.0
#
# product_name  Wine Butterfly Bow Tie  Wing Collar Fly-Front Dress Shirt
# order_id
# 4063                             0.0                                0.0
# 12536                            0.0                                0.0
# 95953                            0.0                                0.0
# 434380                           0.0                                0.0
# 531208                           0.0                                0.0
#
# [5 rows x 180 columns]

# %%
basket.columns
# Out:
# Index(['Apricot Butterfly Bow Tie', 'Barre Pinstripe Tuxedo',
#        'Black & Tartan Tuxedo', 'Black & White Silk Repp Bow Tie',
#        'Black Belt', 'Black Butterfly Bow Tie', 'Black Cotton Necktie',
#        'Black Grosgrain Loafers', 'Black Holly Diamond Bow Tie',
#        'Black Knit Bow Tie',
#        ...
#        'Velvet Jacket Tuxedo', 'Velvet Slip-On Shoes', 'Velvet Tuxedo Jacket ',
#        'Violet Butterfly Bow Tie', 'White Dinner Jacket Tuxedo',
#        'White Linen Necktie', 'White Linen Wide Bow Tie',
#        'White Tuxedo Jacket ', 'Wine Butterfly Bow Tie',
#        'Wing Collar Fly-Front Dress Shirt'],
#       dtype='object', name='product_name', length=180)

# %%
def encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1

basket_sets = basket.applymap(encode_units)

# %%
frequent_itemsets = apriori(basket_sets, min_support=0.01, use_colnames=True)

# %%
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)

# %%
rules.head(20)
# Out:
#                        antecedants                     consequents   support  \
# 0            (Black Leather Shoes)       (Black Butterfly Bow Tie)  0.120786
# 1        (Black Butterfly Bow Tie)           (Black Leather Shoes)  0.238416
# 2      (Black Low Cut Tuxedo Vest)       (Black Butterfly Bow Tie)  0.027916
# 3        (Black Butterfly Bow Tie)     (Black Low Cut Tuxedo Vest)  0.238416
# 4     (Black Patent Leather Shoes)       (Black Butterfly Bow Tie)  0.218492
# 5        (Black Butterfly Bow Tie)    (Black Patent Leather Shoes)  0.238416
# 6              (Black Tuxedo Vest)       (Black Butterfly Bow Tie)  0.025579
# 7        (Black Butterfly Bow Tie)             (Black Tuxedo Vest)  0.238416
# 8   (Cap Toe Shoes in Patent/Calf)       (Black Butterfly Bow Tie)  0.061671
# 9        (Black Butterfly Bow Tie)  (Cap Toe Shoes in Patent/Calf)  0.238416
# 10  (Cotton Fly-Front Dress Shirt)       (Black Butterfly Bow Tie)  0.097847
# 11       (Black Butterfly Bow Tie)  (Cotton Fly-Front Dress Shirt)  0.238416
# 12         (Cotton Wing Tip Shirt)       (Black Butterfly Bow Tie)  0.056369
# 13       (Black Butterfly Bow Tie)         (Cotton Wing Tip Shirt)  0.238416
# 14          (Midnight Blue Tuxedo)       (Black Butterfly Bow Tie)  0.092192
# 15       (Black Butterfly Bow Tie)          (Midnight Blue Tuxedo)  0.238416
# 16            (Notch Lapel Tuxedo)       (Black Butterfly Bow Tie)  0.186820
# 17       (Black Butterfly Bow Tie)            (Notch Lapel Tuxedo)  0.238416
# 18             (Peak Lapel Tuxedo)       (Black Butterfly Bow Tie)  0.150573
# 19       (Black Butterfly Bow Tie)             (Peak Lapel Tuxedo)  0.238416
#
#     confidence      lift
# 0     0.352642  1.479104
# 1     0.178655  1.479104
# 2     0.604198  2.534219
# 3     0.070745  2.534219
# 4     0.482632  2.024326
# 5     0.442299  2.024326
# 6     0.406017  1.702978
# 7     0.043561  1.702978
# 8     0.465026  1.950481
# 9     0.120288  1.950481
# 10    0.325420  1.364927
# 11    0.133554  1.364927
# 12    0.491358  2.060926
# 13    0.116172  2.060926
# 14    0.466457  1.956485
# 15    0.180373  1.956485
# 16    0.504970  2.118019
# 17    0.395688  2.118019
# 18    0.432644  1.814661
# 19    0.273239  1.814661

# %%
rules[ (rules['lift'] >= 5) &
       (rules['confidence'] >= 0.2)].sort_values(by="lift", ascending=False)
# Out:
#                                antecedants  \
# 84                    (Charcoal Suit Vest)
# 85                         (Charcoal Suit)
# 102                  (Grey Cotton Necktie)
# 194       (Brown Leather Shoes, Grey Suit)
# 199                       (Grey Suit Vest)
# 33             (Black Low Cut Tuxedo Vest)
# 32                 (Cotton Wing Tip Shirt)
# 192                           (Brown Belt)
# 189       (Navy Suit, Brown Leather Shoes)
# 109                       (Navy Suit Vest)
# 188                (Navy Suit, Brown Belt)
# 64                            (Brown Belt)
# 65                   (Brown Leather Shoes)
# 120            (Black Low Cut Tuxedo Vest)
# 31             (Black Low Cut Tuxedo Vest)
# 195  (Brown Leather Shoes, Grey Suit Vest)
# 104                            (Grey Suit)
# 105                       (Grey Suit Vest)
#
#                                       consequents   support  confidence  \
# 84                                (Charcoal Suit)  0.022762    0.939516
# 85                           (Charcoal Suit Vest)  0.090914    0.235226
# 102                              (Grey Suit Vest)  0.019239    0.532110
# 194                              (Grey Suit Vest)  0.046266    0.454296
# 199              (Brown Leather Shoes, Grey Suit)  0.054971    0.382353
# 33                        (Cotton Wing Tip Shirt)  0.027916    0.433991
# 32                    (Black Low Cut Tuxedo Vest)  0.056369    0.214930
# 192              (Navy Suit, Brown Leather Shoes)  0.030846    0.363241
# 189                                  (Brown Belt)  0.047833    0.234244
# 109                                   (Navy Suit)  0.019197    0.929018
# 188                         (Brown Leather Shoes)  0.011875    0.943520
# 64                          (Brown Leather Shoes)  0.030846    0.936828
# 65                                   (Brown Belt)  0.136926    0.211045
# 120  (Peak Lapel Tuxedo, Black Butterfly Bow Tie)  0.027916    0.416287
# 31                 (Cap Toe Shoes in Patent/Calf)  0.027916    0.378098
# 195                                   (Grey Suit)  0.021767    0.965618
# 104                              (Grey Suit Vest)  0.160387    0.325395
# 105                                   (Grey Suit)  0.054971    0.949396
#
#           lift
# 84   10.334094
# 85   10.334094
# 102   9.679879
# 194   8.264320
# 199   8.264320
# 33    7.699153
# 32    7.699153
# 192   7.593962
# 189   7.593962
# 109   7.471761
# 188   6.890748
# 64    6.841875
# 65    6.841875
# 120   6.390215
# 31    6.130903
# 195   6.020564
# 104   5.919424
# 105   5.919424
