# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import pymc3 as pm
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy.stats
import seaborn as sns

# %matplotlib inline

# %%
def get_skus(n):
    r_skus = np.arange(1, n+1,1)
    sku_perc = np.random.dirichlet(np.ones(len(r_skus))*1000.,size=1)
    return pd.DataFrame(list(zip(r_skus, sku_perc[0])), columns=['sku', 'sku_percent'])

# %%
# Let's make a few SKUs...somewhere above 20 sku, the sampling below will fail
df_skus = get_skus(56)
df_skus.tail()
# Out:
#     sku  sku_percent
# 51   52     0.017802
# 52   53     0.018757
# 53   54     0.018003
# 54   55     0.017534
# 55   56     0.017851

# %%
n_samples, n_burn = 1000, 3000

# historically, we observe that this style is bought 35% of the time, but this could obviously vary
style_percent_obs = 0.35

# we plan 10000 units of demand for next year
demand_planned = 10000

with pm.Model() as model:

    # we'll model the style distribution as a uniform prior
    style_percent = pm.Beta('style_percent', mu=style_percent_obs, sd=style_percent_obs*.01, testval=style_percent_obs)
    style_demand = pm.Deterministic('style_demand', demand_planned * style_percent)
    
    # then for every sku, we model the sku distribution as a beta prior and
    # we want to determine the distribution of the resulting sku demand to be planned in units
    for _, sku in df_skus.iterrows():
        
        i = sku['sku']
        sku_percent_obs = sku['sku_percent']
        sku_demand_obs = np.ceil(demand_planned * style_percent_obs * sku_percent_obs)
        
        # the SKU % is also modeled as a Beta prior
        sku_perc = pm.Beta(f'sku_percent_{i}', mu=sku_percent_obs, sd=sku_percent_obs*.01, testval=sku_percent_obs)

        sku_demand = pm.Deterministic(f'sku_demand_{i}', style_demand * sku_perc)

        sku_planned = pm.Poisson(f'sku_planned_{i}', mu=sku_demand, observed=sku_demand_obs)

    trace = pm.sample(n_samples, tune=n_burn, random_seed=42, progressbar=True)
# Out:
# INFO (theano.gof.compilelock): Refreshing lock /Users/claus/.theano/compiledir_Darwin-16.7.0-x86_64-i386-64bit-i386-3.6.2-64/lock_dir/lock
# INFO (theano.gof.compilelock): Refreshing lock /Users/claus/.theano/compiledir_Darwin-16.7.0-x86_64-i386-64bit-i386-3.6.2-64/lock_dir/lock
# Auto-assigning NUTS sampler...
# Initializing NUTS using ADVI...
# INFO (theano.gof.compilelock): Refreshing lock /Users/claus/.theano/compiledir_Darwin-16.7.0-x86_64-i386-64bit-i386-3.6.2-64/lock_dir/lock
# ===============================
# 00001	#include <Python.h>
# 00002	#include <iostream>
# 00003	#include "theano_mod_helper.h"
# 00004	#include <math.h>
# 00005	#include <numpy/arrayobject.h>
# 00006	#include <numpy/arrayscalars.h>
# 00007	#include <vector>
# 00008	#include <algorithm>
# 00009	//////////////////////
# 00010	////  Support Code
# 00011	//////////////////////
# 00012
# 00013	    namespace {
# 00014	    struct __struct_compiled_op_m8575ee21d9449135144af93d333e677a {
# 00015	        PyObject* __ERROR;
# 00016
# 00017	        PyObject* storage_V3;
# 00018	PyObject* storage_V5;
# 00019	PyObject* storage_V7;
# 00020	PyObject* storage_V9;
# 00021	PyObject* storage_V11;
# 00022	PyObject* storage_V13;
# 00023	PyObject* storage_V15;
# 00024	PyObject* storage_V17;
# 00025	PyObject* storage_V19;
# 00026	PyObject* storage_V21;
# 00027	PyObject* storage_V23;
# 00028	PyObject* storage_V25;
# 00029	PyObject* storage_V27;
# 00030	PyObject* storage_V29;
# 00031	PyObject* storage_V31;
# 00032	PyObject* storage_V33;
# 00033	PyObject* storage_V35;
# 00034	PyObject* storage_V37;
# 00035	PyObject* storage_V39;
# 00036	PyObject* storage_V41;
# 00037	PyObject* storage_V43;
# 00038	PyObject* storage_V45;
# 00039	PyObject* storage_V47;
# 00040	PyObject* storage_V49;
# 00041	PyObject* storage_V51;
# 00042	PyObject* storage_V53;
# 00043	PyObject* storage_V55;
# 00044	PyObject* storage_V57;
# 00045	PyObject* storage_V59;
# 00046	PyObject* storage_V61;
# 00047	PyObject* storage_V63;
# 00048	PyObject* storage_V65;
# 00049	PyObject* storage_V67;
# 00050	PyObject* storage_V69;
# 00051	PyObject* storage_V71;
# 00052	PyObject* storage_V73;
# 00053	PyObject* storage_V75;
# 00054	PyObject* storage_V77;
# 00055	PyObject* storage_V79;
# 00056	PyObject* storage_V81;
# 00057	PyObject* storage_V83;
# 00058	PyObject* storage_V85;
# 00059	PyObject* storage_V87;
# 00060	PyObject* storage_V89;
# 00061	PyObject* storage_V91;
# 00062	PyObject* storage_V93;
# 00063	PyObject* storage_V95;
# 00064	PyObject* storage_V97;
# 00065	PyObject* storage_V99;
# 00066	PyObject* storage_V101;
# 00067	PyObject* storage_V103;
# 00068	PyObject* storage_V105;
# 00069	PyObject* storage_V107;
# 00070	PyObject* storage_V109;
# 00071	PyObject* storage_V111;
# 00072	PyObject* storage_V113;
# 00073	PyObject* storage_V115;
# 00074	PyObject* storage_V117;
# 00075	PyObject* storage_V119;
# 00076	PyObject* storage_V121;
# 00077	PyObject* storage_V123;
# 00078	PyObject* storage_V125;
# 00079	PyObject* storage_V127;
# 00080	PyObject* storage_V129;
# 00081	PyObject* storage_V131;
# 00082	PyObject* storage_V133;
# 00083	PyObject* storage_V135;
# 00084	PyObject* storage_V137;
# 00085	PyObject* storage_V139;
# 00086	PyObject* storage_V141;
# 00087	PyObject* storage_V143;
# 00088	PyObject* storage_V145;
# 00089	PyObject* storage_V147;
# 00090	PyObject* storage_V149;
# 00091	PyObject* storage_V151;
# 00092	PyObject* storage_V153;
# 00093	PyObject* storage_V155;
# 00094	PyObject* storage_V157;
# 00095	PyObject* storage_V159;
# 00096	PyObject* storage_V161;
# 00097	PyObject* storage_V163;
# 00098	PyObject* storage_V165;
# 00099	PyObject* storage_V167;
# 00100	PyObject* storage_V169;
# 00101	PyObject* storage_V171;
# 00102	PyObject* storage_V173;
# 00103	PyObject* storage_V175;
# 00104	PyObject* storage_V177;
# 00105	PyObject* storage_V179;
# 00106	PyObject* storage_V181;
# 00107	PyObject* storage_V183;
# 00108	PyObject* storage_V185;
# 00109	PyObject* storage_V187;
# 00110	PyObject* storage_V189;
# 00111	PyObject* storage_V191;
# 00112	PyObject* storage_V193;
# 00113	PyObject* storage_V195;
# 00114	PyObject* storage_V197;
# 00115	PyObject* storage_V199;
# 00116	PyObject* storage_V201;
# 00117	PyObject* storage_V203;
# 00118	PyObject* storage_V205;
# 00119	PyObject* storage_V207;
# 00120	PyObject* storage_V209;
# 00121	PyObject* storage_V211;
# 00122	PyObject* storage_V213;
# 00123	PyObject* storage_V215;
# 00124	PyObject* storage_V217;
# 00125	PyObject* storage_V219;
# 00126	PyObject* storage_V221;
# 00127	PyObject* storage_V223;
# 00128	PyObject* storage_V225;
# 00129	PyObject* storage_V227;
# 00130	PyObject* storage_V229;
# 00131	PyObject* storage_V231;
# 00132	PyObject* storage_V233;
# 00133	PyObject* storage_V235;
# 00134	PyObject* storage_V237;
# 00135	PyObject* storage_V239;
# 00136	PyObject* storage_V241;
# 00137	PyObject* storage_V243;
# 00138	PyObject* storage_V245;
# 00139	PyObject* storage_V247;
# 00140	PyObject* storage_V249;
# 00141	PyObject* storage_V251;
# 00142	PyObject* storage_V253;
# 00143	PyObject* storage_V255;
# 00144	PyObject* storage_V257;
# 00145	PyObject* storage_V259;
# 00146	PyObject* storage_V261;
# 00147	PyObject* storage_V263;
# 00148	PyObject* storage_V265;
# 00149	PyObject* storage_V267;
# 00150	PyObject* storage_V269;
# 00151	PyObject* storage_V271;
# 00152	PyObject* storage_V273;
# 00153	PyObject* storage_V275;
# 00154	PyObject* storage_V277;
# 00155	PyObject* storage_V279;
# 00156	PyObject* storage_V281;
# 00157	PyObject* storage_V283;
# 00158	PyObject* storage_V285;
# 00159	PyObject* storage_V287;
# 00160	PyObject* storage_V289;
# 00161	PyObject* storage_V291;
# 00162	PyObject* storage_V293;
# 00163	PyObject* storage_V295;
# 00164	PyObject* storage_V297;
# 00165	PyObject* storage_V299;
# 00166	PyObject* storage_V301;
# 00167	PyObject* storage_V303;
# 00168	PyObject* storage_V305;
# 00169	PyObject* storage_V307;
# 00170	PyObject* storage_V309;
# 00171	PyObject* storage_V311;
# 00172	PyObject* storage_V313;
# 00173	PyObject* storage_V315;
# 00174	PyObject* storage_V317;
# 00175	PyObject* storage_V319;
# 00176	PyObject* storage_V321;
# 00177	PyObject* storage_V323;
# 00178	PyObject* storage_V325;
# 00179	PyObject* storage_V327;
# 00180	PyObject* storage_V329;
# 00181	PyObject* storage_V331;
# 00182	PyObject* storage_V333;
# 00183	PyObject* storage_V335;
# 00184	PyObject* storage_V337;
# 00185	PyObject* storage_V339;
# 00186	PyObject* storage_V341;
# 00187	PyObject* storage_V343;
# 00188	PyObject* storage_V345;
# 00189	PyObject* storage_V347;
# 00190	PyObject* storage_V349;
# 00191	PyObject* storage_V351;
# 00192	PyObject* storage_V353;
# 00193	PyObject* storage_V355;
# 00194	PyObject* storage_V357;
# 00195	PyObject* storage_V359;
# 00196	PyObject* storage_V361;
# 00197	PyObject* storage_V363;
# 00198	PyObject* storage_V365;
# 00199	PyObject* storage_V367;
# 00200	PyObject* storage_V369;
# 00201	PyObject* storage_V371;
# 00202	PyObject* storage_V373;
# 00203	PyObject* storage_V375;
# 00204	PyObject* storage_V377;
# 00205	PyObject* storage_V379;
# 00206	PyObject* storage_V381;
# 00207	PyObject* storage_V383;
# 00208	PyObject* storage_V385;
# 00209	PyObject* storage_V387;
# 00210	PyObject* storage_V389;
# 00211	PyObject* storage_V391;
# 00212	PyObject* storage_V393;
# 00213	PyObject* storage_V395;
# 00214	PyObject* storage_V397;
# 00215	PyObject* storage_V399;
# 00216	PyObject* storage_V401;
# 00217	PyObject* storage_V403;
# 00218	PyObject* storage_V405;
# 00219	PyObject* storage_V407;
# 00220	PyObject* storage_V409;
# 00221	PyObject* storage_V411;
# 00222	PyObject* storage_V413;
# 00223	PyObject* storage_V415;
# 00224	PyObject* storage_V417;
# 00225	PyObject* storage_V419;
# 00226	PyObject* storage_V421;
# 00227	PyObject* storage_V423;
# 00228	PyObject* storage_V425;
# 00229	PyObject* storage_V427;
# 00230	PyObject* storage_V429;
# 00231	PyObject* storage_V431;
# 00232	PyObject* storage_V433;
# 00233	PyObject* storage_V435;
# 00234	PyObject* storage_V437;
# 00235	PyObject* storage_V439;
# 00236	PyObject* storage_V441;
# 00237	PyObject* storage_V443;
# 00238	PyObject* storage_V445;
# 00239	PyObject* storage_V447;
# 00240	PyObject* storage_V449;
# 00241	PyObject* storage_V451;
# 00242	PyObject* storage_V453;
# 00243	PyObject* storage_V455;
# 00244	PyObject* storage_V457;
# 00245	PyObject* storage_V459;
# 00246	PyObject* storage_V461;
# 00247	PyObject* storage_V463;
# 00248	PyObject* storage_V465;
# 00249	PyObject* storage_V467;
# 00250	PyObject* storage_V469;
# 00251	PyObject* storage_V471;
# 00252	PyObject* storage_V473;
# 00253	PyObject* storage_V475;
# 00254	PyObject* storage_V477;
# 00255	PyObject* storage_V479;
# 00256	PyObject* storage_V481;
# 00257	PyObject* storage_V483;
# 00258	PyObject* storage_V485;
# 00259	PyObject* storage_V487;
# 00260	PyObject* storage_V489;
# 00261	PyObject* storage_V491;
# 00262	PyObject* storage_V493;
# 00263	PyObject* storage_V495;
# 00264	PyObject* storage_V497;
# 00265	PyObject* storage_V499;
# 00266	PyObject* storage_V501;
# 00267	PyObject* storage_V503;
# 00268	PyObject* storage_V505;
# 00269	PyObject* storage_V507;
# 00270	PyObject* storage_V509;
# 00271	PyObject* storage_V511;
# 00272	PyObject* storage_V513;
# 00273	PyObject* storage_V515;
# 00274	PyObject* storage_V517;
# 00275	PyObject* storage_V519;
# 00276	PyObject* storage_V521;
# 00277	PyObject* storage_V523;
# 00278	PyObject* storage_V525;
# 00279	PyObject* storage_V527;
# 00280	PyObject* storage_V529;
# 00281	PyObject* storage_V531;
# 00282	PyObject* storage_V533;
# 00283	PyObject* storage_V535;
# 00284	PyObject* storage_V537;
# 00285	PyObject* storage_V539;
# 00286	PyObject* storage_V541;
# 00287	PyObject* storage_V543;
# 00288	PyObject* storage_V545;
# 00289	PyObject* storage_V547;
# 00290	PyObject* storage_V549;
# 00291	PyObject* storage_V551;
# 00292	PyObject* storage_V553;
# 00293	PyObject* storage_V555;
# 00294	PyObject* storage_V557;
# 00295	PyObject* storage_V559;
# 00296	PyObject* storage_V561;
# 00297	PyObject* storage_V563;
# 00298	PyObject* storage_V565;
# 00299	PyObject* storage_V567;
# 00300	PyObject* storage_V569;
# 00301	PyObject* storage_V571;
# 00302	PyObject* storage_V573;
# 00303	PyObject* storage_V575;
# 00304	PyObject* storage_V577;
# 00305	PyObject* storage_V579;
# 00306	PyObject* storage_V581;
# 00307	PyObject* storage_V583;
# 00308	PyObject* storage_V585;
# 00309	PyObject* storage_V587;
# 00310	PyObject* storage_V589;
# 00311	PyObject* storage_V591;
# 00312	PyObject* storage_V593;
# 00313	PyObject* storage_V595;
# 00314	PyObject* storage_V597;
# 00315	PyObject* storage_V599;
# 00316	PyObject* storage_V601;
# 00317	PyObject* storage_V603;
# 00318	PyObject* storage_V605;
# 00319	PyObject* storage_V607;
# 00320	PyObject* storage_V609;
# 00321	PyObject* storage_V611;
# 00322	PyObject* storage_V613;
# 00323	PyObject* storage_V615;
# 00324	PyObject* storage_V617;
# 00325	PyObject* storage_V619;
# 00326	PyObject* storage_V621;
# 00327	PyObject* storage_V623;
# 00328	PyObject* storage_V625;
# 00329	PyObject* storage_V627;
# 00330	PyObject* storage_V629;
# 00331	PyObject* storage_V631;
# 00332	PyObject* storage_V633;
# 00333	PyObject* storage_V635;
# 00334	PyObject* storage_V637;
# 00335	PyObject* storage_V639;
# 00336	PyObject* storage_V641;
# 00337	PyObject* storage_V643;
# 00338	PyObject* storage_V645;
# 00339	PyObject* storage_V647;
# 00340	PyObject* storage_V649;
# 00341	PyObject* storage_V651;
# 00342	PyObject* storage_V653;
# 00343	PyObject* storage_V655;
# 00344	PyObject* storage_V657;
# 00345	PyObject* storage_V659;
# 00346	PyObject* storage_V661;
# 00347	PyObject* storage_V663;
# 00348	PyObject* storage_V665;
# 00349	PyObject* storage_V667;
# 00350	PyObject* storage_V669;
# 00351	PyObject* storage_V671;
# 00352	PyObject* storage_V673;
# 00353	PyObject* storage_V675;
# 00354	PyObject* storage_V677;
# 00355	PyObject* storage_V679;
# 00356	PyObject* storage_V681;
# 00357	PyObject* storage_V683;
# 00358	PyObject* storage_V685;
# 00359	PyObject* storage_V687;
# 00360	PyObject* storage_V689;
# 00361	PyObject* storage_V691;
# 00362	PyObject* storage_V693;
# 00363	PyObject* storage_V695;
# 00364	PyObject* storage_V697;
# 00365	PyObject* storage_V699;
# 00366	PyObject* storage_V701;
# 00367	PyObject* storage_V703;
# 00368	PyObject* storage_V705;
# 00369	PyObject* storage_V707;
# 00370	PyObject* storage_V709;
# 00371	PyObject* storage_V711;
# 00372	PyObject* storage_V713;
# 00373	PyObject* storage_V715;
# 00374	PyObject* storage_V717;
# 00375	PyObject* storage_V719;
# 00376	PyObject* storage_V721;
# 00377	PyObject* storage_V723;
# 00378	PyObject* storage_V725;
# 00379	PyObject* storage_V727;
# 00380	PyObject* storage_V729;
# 00381	PyObject* storage_V731;
# 00382	PyObject* storage_V733;
# 00383	PyObject* storage_V735;
# 00384	PyObject* storage_V737;
# 00385	PyObject* storage_V739;
# 00386	PyObject* storage_V741;
# 00387	PyObject* storage_V743;
# 00388	PyObject* storage_V745;
# 00389	PyObject* storage_V747;
# 00390	PyObject* storage_V749;
# 00391	PyObject* storage_V751;
# 00392	PyObject* storage_V753;
# 00393	PyObject* storage_V755;
# 00394	PyObject* storage_V757;
# 00395	PyObject* storage_V759;
# 00396	PyObject* storage_V761;
# 00397	PyObject* storage_V763;
# 00398	PyObject* storage_V765;
# 00399	PyObject* storage_V767;
# 00400	PyObject* storage_V769;
# 00401	PyObject* storage_V771;
# 00402	PyObject* storage_V773;
# 00403	PyObject* storage_V775;
# 00404	PyObject* storage_V777;
# 00405	PyObject* storage_V779;
# 00406	PyObject* storage_V781;
# 00407	PyObject* storage_V783;
# 00408	PyObject* storage_V785;
# 00409	PyObject* storage_V787;
# 00410	PyObject* storage_V789;
# 00411	PyObject* storage_V791;
# 00412	PyObject* storage_V793;
# 00413	PyObject* storage_V795;
# 00414	PyObject* storage_V797;
# 00415	PyObject* storage_V799;
# 00416	PyObject* storage_V801;
# 00417	PyObject* storage_V803;
# 00418	PyObject* storage_V805;
# 00419	PyObject* storage_V807;
# 00420	PyObject* storage_V809;
# 00421	PyObject* storage_V811;
# 00422	PyObject* storage_V813;
# 00423	PyObject* storage_V815;
# 00424	PyObject* storage_V817;
# 00425	PyObject* storage_V819;
# 00426	PyObject* storage_V821;
# 00427	PyObject* storage_V823;
# 00428	PyObject* storage_V825;
# 00429	PyObject* storage_V827;
# 00430	PyObject* storage_V829;
# 00431	PyObject* storage_V831;
# 00432	PyObject* storage_V833;
# 00433	PyObject* storage_V835;
# 00434	PyObject* storage_V837;
# 00435	PyObject* storage_V839;
# 00436	PyObject* storage_V841;
# 00437	PyObject* storage_V843;
# 00438	PyObject* storage_V845;
# 00439	PyObject* storage_V847;
# 00440	PyObject* storage_V849;
# 00441	PyObject* storage_V851;
# 00442	PyObject* storage_V853;
# 00443	PyObject* storage_V855;
# 00444	PyObject* storage_V857;
# 00445	PyObject* storage_V859;
# 00446	PyObject* storage_V861;
# 00447	PyObject* storage_V863;
# 00448	PyObject* storage_V865;
# 00449	PyObject* storage_V867;
# 00450	PyObject* storage_V869;
# 00451	PyObject* storage_V871;
# 00452	PyObject* storage_V873;
# 00453	PyObject* storage_V875;
# 00454	PyObject* storage_V877;
# 00455	PyObject* storage_V879;
# 00456	PyObject* storage_V881;
# 00457	PyObject* storage_V883;
# 00458	PyObject* storage_V885;
# 00459	PyObject* storage_V887;
# 00460	PyObject* storage_V889;
# 00461	PyObject* storage_V891;
# 00462	PyObject* storage_V893;
# 00463	PyObject* storage_V895;
# 00464	PyObject* storage_V897;
# 00465	PyObject* storage_V899;
# 00466	PyObject* storage_V901;
# 00467	PyObject* storage_V903;
# 00468	PyObject* storage_V905;
# 00469	PyObject* storage_V907;
# 00470	PyObject* storage_V909;
# 00471	PyObject* storage_V911;
# 00472	PyObject* storage_V913;
# 00473	PyObject* storage_V915;
# 00474	PyObject* storage_V917;
# 00475	PyObject* storage_V919;
# 00476	PyObject* storage_V921;
# 00477	PyObject* storage_V923;
# 00478	PyObject* storage_V925;
# 00479	PyObject* storage_V927;
# 00480	PyObject* storage_V929;
# 00481	PyObject* storage_V931;
# 00482	PyObject* storage_V933;
# 00483	PyObject* storage_V935;
# 00484	PyObject* storage_V937;
# 00485	PyObject* storage_V939;
# 00486	PyObject* storage_V941;
# 00487	PyObject* storage_V943;
# 00488	PyObject* storage_V945;
# 00489	PyObject* storage_V947;
# 00490	PyObject* storage_V949;
# 00491	PyObject* storage_V951;
# 00492	PyObject* storage_V953;
# 00493	PyObject* storage_V955;
# 00494	PyObject* storage_V957;
# 00495	PyObject* storage_V959;
# 00496	PyObject* storage_V961;
# 00497	PyObject* storage_V963;
# 00498	PyObject* storage_V965;
# 00499	PyObject* storage_V967;
# 00500	PyObject* storage_V969;
# 00501	PyObject* storage_V971;
# 00502	PyObject* storage_V973;
# 00503	PyObject* storage_V975;
# 00504	PyObject* storage_V977;
# 00505	PyObject* storage_V979;
# 00506	PyObject* storage_V981;
# 00507	PyObject* storage_V983;
# 00508	PyObject* storage_V985;
# 00509	PyObject* storage_V987;
# 00510	PyObject* storage_V989;
# 00511	PyObject* storage_V991;
# 00512	PyObject* storage_V993;
# 00513	PyObject* storage_V995;
# 00514	PyObject* storage_V997;
# 00515	PyObject* storage_V999;
# 00516	PyObject* storage_V1001;
# 00517	PyObject* storage_V1003;
# 00518	PyObject* storage_V1005;
# 00519	PyObject* storage_V1007;
# 00520	PyObject* storage_V1009;
# 00521	PyObject* storage_V1011;
# 00522	PyObject* storage_V1013;
# 00523	PyObject* storage_V1015;
# 00524	PyObject* storage_V1017;
# 00525	PyObject* storage_V1019;
# 00526	PyObject* storage_V1021;
# 00527	PyObject* storage_V1023;
# 00528	PyObject* storage_V1025;
# 00529	PyObject* storage_V1027;
# 00530	PyObject* storage_V1029;
# 00531	PyObject* storage_V1031;
# 00532	PyObject* storage_V1033;
# 00533	PyObject* storage_V1035;
# 00534	PyObject* storage_V1037;
# 00535	PyObject* storage_V1039;
# 00536	PyObject* storage_V1041;
# 00537	PyObject* storage_V1043;
# 00538	PyObject* storage_V1045;
# 00539	PyObject* storage_V1047;
# 00540	PyObject* storage_V1049;
# 00541	PyObject* storage_V1051;
# 00542	PyObject* storage_V1053;
# 00543	PyObject* storage_V1055;
# 00544	PyObject* storage_V1057;
# 00545	PyObject* storage_V1059;
# 00546	PyObject* storage_V1061;
# 00547	PyObject* storage_V1063;
# 00548	PyObject* storage_V1065;
# 00549	PyObject* storage_V1067;
# 00550	PyObject* storage_V1069;
# 00551	PyObject* storage_V1071;
# 00552	PyObject* storage_V1073;
# 00553	PyObject* storage_V1075;
# 00554	PyObject* storage_V1077;
# 00555	PyObject* storage_V1079;
# 00556	PyObject* storage_V1081;
# 00557	PyObject* storage_V1083;
# 00558	PyObject* storage_V1085;
# 00559	PyObject* storage_V1087;
# 00560	PyObject* storage_V1089;
# 00561	PyObject* storage_V1091;
# 00562	PyObject* storage_V1093;
# 00563	PyObject* storage_V1095;
# 00564	PyObject* storage_V1097;
# 00565	PyObject* storage_V1099;
# 00566	PyObject* storage_V1101;
# 00567	PyObject* storage_V1103;
# 00568	PyObject* storage_V1105;
# 00569	PyObject* storage_V1107;
# 00570	PyObject* storage_V1109;
# 00571	PyObject* storage_V1111;
# 00572	PyObject* storage_V1113;
# 00573	PyObject* storage_V1115;
# 00574	PyObject* storage_V1117;
# 00575	PyObject* storage_V1119;
# 00576	PyObject* storage_V1121;
# 00577	PyObject* storage_V1123;
# 00578	PyObject* storage_V1125;
# 00579	PyObject* storage_V1127;
# 00580	PyObject* storage_V1129;
# 00581	PyObject* storage_V1131;
# 00582	PyObject* storage_V1133;
# 00583	PyObject* storage_V1135;
# 00584	PyObject* storage_V1137;
# 00585	PyObject* storage_V1139;
# 00586	PyObject* storage_V1141;
# 00587	PyObject* storage_V1143;
# 00588	PyObject* storage_V1145;
# 00589	PyObject* storage_V1147;
# 00590	PyObject* storage_V1149;
# 00591	PyObject* storage_V1151;
# 00592	PyObject* storage_V1153;
# 00593	PyObject* storage_V1155;
# 00594	PyObject* storage_V1157;
# 00595	PyObject* storage_V1159;
# 00596	PyObject* storage_V1161;
# 00597	PyObject* storage_V1163;
# 00598	PyObject* storage_V1165;
# 00599	PyObject* storage_V1167;
# 00600	PyObject* storage_V1169;
# 00601	PyObject* storage_V1171;
# 00602	PyObject* storage_V1173;
# 00603	PyObject* storage_V1175;
# 00604	PyObject* storage_V1177;
# 00605	PyObject* storage_V1179;
# 00606	PyObject* storage_V1181;
# 00607	PyObject* storage_V1183;
# 00608	PyObject* storage_V1185;
# 00609	PyObject* storage_V1187;
# 00610	PyObject* storage_V1189;
# 00611	PyObject* storage_V1191;
# 00612	PyObject* storage_V1193;
# 00613	PyObject* storage_V1195;
# 00614	PyObject* storage_V1197;
# 00615	PyObject* storage_V1199;
# 00616	PyObject* storage_V1201;
# 00617	PyObject* storage_V1203;
# 00618	PyObject* storage_V1205;
# 00619	PyObject* storage_V1207;
# 00620	PyObject* storage_V1209;
# 00621	PyObject* storage_V1211;
# 00622	PyObject* storage_V1213;
# 00623	PyObject* storage_V1215;
# 00624	PyObject* storage_V1217;
# 00625	PyObject* storage_V1219;
# 00626	PyObject* storage_V1221;
# 00627	PyObject* storage_V1223;
# 00628	PyObject* storage_V1225;
# 00629	PyObject* storage_V1227;
# 00630	PyObject* storage_V1229;
# 00631	PyObject* storage_V1231;
# 00632	PyObject* storage_V1233;
# 00633	PyObject* storage_V1235;
# 00634	PyObject* storage_V1237;
# 00635	PyObject* storage_V1239;
# 00636	PyObject* storage_V1241;
# 00637	PyObject* storage_V1243;
# 00638	PyObject* storage_V1245;
# 00639	PyObject* storage_V1247;
# 00640	PyObject* storage_V1249;
# 00641	PyObject* storage_V1251;
# 00642	PyObject* storage_V1253;
# 00643	PyObject* storage_V1255;
# 00644	PyObject* storage_V1257;
# 00645	PyObject* storage_V1259;
# 00646	PyObject* storage_V1261;
# 00647	PyObject* storage_V1263;
# 00648	PyObject* storage_V1265;
# 00649	PyObject* storage_V1267;
# 00650	PyObject* storage_V1269;
# 00651	PyObject* storage_V1271;
# 00652	PyObject* storage_V1273;
# 00653	PyObject* storage_V1275;
# 00654	PyObject* storage_V1277;
# 00655	PyObject* storage_V1279;
# 00656	PyObject* storage_V1281;
# 00657	PyObject* storage_V1283;
# 00658	PyObject* storage_V1285;
# 00659	PyObject* storage_V1287;
# 00660	PyObject* storage_V1289;
# 00661	PyObject* storage_V1291;
# 00662	PyObject* storage_V1293;
# 00663	PyObject* storage_V1295;
# 00664	PyObject* storage_V1297;
# 00665	PyObject* storage_V1299;
# 00666	PyObject* storage_V1301;
# 00667	PyObject* storage_V1303;
# 00668	PyObject* storage_V1305;
# 00669	PyObject* storage_V1307;
# 00670	PyObject* storage_V1309;
# 00671	PyObject* storage_V1311;
# 00672	PyObject* storage_V1313;
# 00673	PyObject* storage_V1315;
# 00674	PyObject* storage_V1317;
# 00675	PyObject* storage_V1319;
# 00676	PyObject* storage_V1321;
# 00677	PyObject* storage_V1323;
# 00678	PyObject* storage_V1325;
# 00679	PyObject* storage_V1327;
# 00680	PyObject* storage_V1329;
# 00681	PyObject* storage_V1331;
# 00682	PyObject* storage_V1333;
# 00683	PyObject* storage_V1335;
# 00684	PyObject* storage_V1337;
# 00685	PyObject* storage_V1339;
# 00686	PyObject* storage_V1341;
# 00687	PyObject* storage_V1343;
# 00688	PyObject* storage_V1345;
# 00689	PyObject* storage_V1347;
# 00690	PyObject* storage_V1349;
# 00691	PyObject* storage_V1351;
# 00692	PyObject* storage_V1353;
# 00693	PyObject* storage_V1355;
# 00694	PyObject* storage_V1357;
# 00695	PyObject* storage_V1359;
# 00696	PyObject* storage_V1361;
# 00697	PyObject* storage_V1363;
# 00698	PyObject* storage_V1365;
# 00699	PyObject* storage_V1367;
# 00700	PyObject* storage_V1369;
# 00701	PyObject* storage_V1371;
# 00702	PyObject* storage_V1373;
# 00703	PyObject* storage_V1375;
# 00704	PyObject* storage_V1377;
# 00705	PyObject* storage_V1379;
# 00706	PyObject* storage_V1381;
# 00707	PyObject* storage_V1383;
# 00708	PyObject* storage_V1385;
# 00709	PyObject* storage_V1387;
# 00710	PyObject* storage_V1389;
# 00711	PyObject* storage_V1391;
# 00712	PyObject* storage_V1393;
# 00713	PyObject* storage_V1395;
# 00714	PyObject* storage_V1397;
# 00715	PyObject* storage_V1399;
# 00716	PyObject* storage_V1401;
# 00717	PyObject* storage_V1403;
# 00718	PyObject* storage_V1405;
# 00719	PyObject* storage_V1407;
# 00720	PyObject* storage_V1409;
# 00721	PyObject* storage_V1;
# 00722
# 00723
# 00724	        __struct_compiled_op_m8575ee21d9449135144af93d333e677a() {
# 00725	            // This is only somewhat safe because we:
# 00726	            //  1) Are not a virtual class
# 00727	            //  2) Do not use any virtual classes in the members
# 00728	            //  3) Deal with mostly POD and pointers
# 00729
# 00730	            // If this changes, we would have to revise this, but for
# 00731	            // now I am tired of chasing segfaults because
# 00732	            // initialization code had an error and some pointer has
# 00733	            // a junk value.
# 00734	            memset(this, 0, sizeof(*this));
# 00735	        }
# 00736	        ~__struct_compiled_op_m8575ee21d9449135144af93d333e677a(void) {
# 00737	            cleanup();
# 00738	        }
# 00739
# 00740	        int init(PyObject* __ERROR, PyObject* storage_V3, PyObject* storage_V5, PyObject* storage_V7, PyObject* storage_V9, PyObject* storage_V11, PyObject* storage_V13, PyObject* storage_V15, PyObject* storage_V17, PyObject* storage_V19, PyObject* storage_V21, PyObject* storage_V23, PyObject* storage_V25, PyObject* storage_V27, PyObject* storage_V29, PyObject* storage_V31, PyObject* storage_V33, PyObject* storage_V35, PyObject* storage_V37, PyObject* storage_V39, PyObject* storage_V41, PyObject* storage_V43, PyObject* storage_V45, PyObject* storage_V47, PyObject* storage_V49, PyObject* storage_V51, PyObject* storage_V53, PyObject* storage_V55, PyObject* storage_V57, PyObject* storage_V59, PyObject* storage_V61, PyObject* storage_V63, PyObject* storage_V65, PyObject* storage_V67, PyObject* storage_V69, PyObject* storage_V71, PyObject* storage_V73, PyObject* storage_V75, PyObject* storage_V77, PyObject* storage_V79, PyObject* storage_V81, PyObject* storage_V83, PyObject* storage_V85, PyObject* storage_V87, PyObject* storage_V89, PyObject* storage_V91, PyObject* storage_V93, PyObject* storage_V95, PyObject* storage_V97, PyObject* storage_V99, PyObject* storage_V101, PyObject* storage_V103, PyObject* storage_V105, PyObject* storage_V107, PyObject* storage_V109, PyObject* storage_V111, PyObject* storage_V113, PyObject* storage_V115, PyObject* storage_V117, PyObject* storage_V119, PyObject* storage_V121, PyObject* storage_V123, PyObject* storage_V125, PyObject* storage_V127, PyObject* storage_V129, PyObject* storage_V131, PyObject* storage_V133, PyObject* storage_V135, PyObject* storage_V137, PyObject* storage_V139, PyObject* storage_V141, PyObject* storage_V143, PyObject* storage_V145, PyObject* storage_V147, PyObject* storage_V149, PyObject* storage_V151, PyObject* storage_V153, PyObject* storage_V155, PyObject* storage_V157, PyObject* storage_V159, PyObject* storage_V161, PyObject* storage_V163, PyObject* storage_V165, PyObject* storage_V167, PyObject* storage_V169, PyObject* storage_V171, PyObject* storage_V173, PyObject* storage_V175, PyObject* storage_V177, PyObject* storage_V179, PyObject* storage_V181, PyObject* storage_V183, PyObject* storage_V185, PyObject* storage_V187, PyObject* storage_V189, PyObject* storage_V191, PyObject* storage_V193, PyObject* storage_V195, PyObject* storage_V197, PyObject* storage_V199, PyObject* storage_V201, PyObject* storage_V203, PyObject* storage_V205, PyObject* storage_V207, PyObject* storage_V209, PyObject* storage_V211, PyObject* storage_V213, PyObject* storage_V215, PyObject* storage_V217, PyObject* storage_V219, PyObject* storage_V221, PyObject* storage_V223, PyObject* storage_V225, PyObject* storage_V227, PyObject* storage_V229, PyObject* storage_V231, PyObject* storage_V233, PyObject* storage_V235, PyObject* storage_V237, PyObject* storage_V239, PyObject* storage_V241, PyObject* storage_V243, PyObject* storage_V245, PyObject* storage_V247, PyObject* storage_V249, PyObject* storage_V251, PyObject* storage_V253, PyObject* storage_V255, PyObject* storage_V257, PyObject* storage_V259, PyObject* storage_V261, PyObject* storage_V263, PyObject* storage_V265, PyObject* storage_V267, PyObject* storage_V269, PyObject* storage_V271, PyObject* storage_V273, PyObject* storage_V275, PyObject* storage_V277, PyObject* storage_V279, PyObject* storage_V281, PyObject* storage_V283, PyObject* storage_V285, PyObject* storage_V287, PyObject* storage_V289, PyObject* storage_V291, PyObject* storage_V293, PyObject* storage_V295, PyObject* storage_V297, PyObject* storage_V299, PyObject* storage_V301, PyObject* storage_V303, PyObject* storage_V305, PyObject* storage_V307, PyObject* storage_V309, PyObject* storage_V311, PyObject* storage_V313, PyObject* storage_V315, PyObject* storage_V317, PyObject* storage_V319, PyObject* storage_V321, PyObject* storage_V323, PyObject* storage_V325, PyObject* storage_V327, PyObject* storage_V329, PyObject* storage_V331, PyObject* storage_V333, PyObject* storage_V335, PyO ...
# 00741	            Py_XINCREF(storage_V3);
# 00742	Py_XINCREF(storage_V5);
# 00743	Py_XINCREF(storage_V7);
# 00744	Py_XINCREF(storage_V9);
# 00745	Py_XINCREF(storage_V11);
# 00746	Py_XINCREF(storage_V13);
# 00747	Py_XINCREF(storage_V15);
# 00748	Py_XINCREF(storage_V17);
# 00749	Py_XINCREF(storage_V19);
# 00750	Py_XINCREF(storage_V21);
# 00751	Py_XINCREF(storage_V23);
# 00752	Py_XINCREF(storage_V25);
# 00753	Py_XINCREF(storage_V27);
# 00754	Py_XINCREF(storage_V29);
# 00755	Py_XINCREF(storage_V31);
# 00756	Py_XINCREF(storage_V33);
# 00757	Py_XINCREF(storage_V35);
# 00758	Py_XINCREF(storage_V37);
# 00759	Py_XINCREF(storage_V39);
# 00760	Py_XINCREF(storage_V41);
# 00761	Py_XINCREF(storage_V43);
# 00762	Py_XINCREF(storage_V45);
# 00763	Py_XINCREF(storage_V47);
# 00764	Py_XINCREF(storage_V49);
# 00765	Py_XINCREF(storage_V51);
# 00766	Py_XINCREF(storage_V53);
# 00767	Py_XINCREF(storage_V55);
# 00768	Py_XINCREF(storage_V57);
# 00769	Py_XINCREF(storage_V59);
# 00770	Py_XINCREF(storage_V61);
# 00771	Py_XINCREF(storage_V63);
# 00772	Py_XINCREF(storage_V65);
# 00773	Py_XINCREF(storage_V67);
# 00774	Py_XINCREF(storage_V69);
# 00775	Py_XINCREF(storage_V71);
# 00776	Py_XINCREF(storage_V73);
# 00777	Py_XINCREF(storage_V75);
# 00778	Py_XINCREF(storage_V77);
# 00779	Py_XINCREF(storage_V79);
# 00780	Py_XINCREF(storage_V81);
# 00781	Py_XINCREF(storage_V83);
# 00782	Py_XINCREF(storage_V85);
# 00783	Py_XINCREF(storage_V87);
# 00784	Py_XINCREF(storage_V89);
# 00785	Py_XINCREF(storage_V91);
# 00786	Py_XINCREF(storage_V93);
# 00787	Py_XINCREF(storage_V95);
# 00788	Py_XINCREF(storage_V97);
# 00789	Py_XINCREF(storage_V99);
# 00790	Py_XINCREF(storage_V101);
# 00791	Py_XINCREF(storage_V103);
# 00792	Py_XINCREF(storage_V105);
# 00793	Py_XINCREF(storage_V107);
# 00794	Py_XINCREF(storage_V109);
# 00795	Py_XINCREF(storage_V111);
# 00796	Py_XINCREF(storage_V113);
# 00797	Py_XINCREF(storage_V115);
# 00798	Py_XINCREF(storage_V117);
# 00799	Py_XINCREF(storage_V119);
# 00800	Py_XINCREF(storage_V121);
# 00801	Py_XINCREF(storage_V123);
# 00802	Py_XINCREF(storage_V125);
# 00803	Py_XINCREF(storage_V127);
# 00804	Py_XINCREF(storage_V129);
# 00805	Py_XINCREF(storage_V131);
# 00806	Py_XINCREF(storage_V133);
# 00807	Py_XINCREF(storage_V135);
# 00808	Py_XINCREF(storage_V137);
# 00809	Py_XINCREF(storage_V139);
# 00810	Py_XINCREF(storage_V141);
# 00811	Py_XINCREF(storage_V143);
# 00812	Py_XINCREF(storage_V145);
# 00813	Py_XINCREF(storage_V147);
# 00814	Py_XINCREF(storage_V149);
# 00815	Py_XINCREF(storage_V151);
# 00816	Py_XINCREF(storage_V153);
# 00817	Py_XINCREF(storage_V155);
# 00818	Py_XINCREF(storage_V157);
# 00819	Py_XINCREF(storage_V159);
# 00820	Py_XINCREF(storage_V161);
# 00821	Py_XINCREF(storage_V163);
# 00822	Py_XINCREF(storage_V165);
# 00823	Py_XINCREF(storage_V167);
# 00824	Py_XINCREF(storage_V169);
# 00825	Py_XINCREF(storage_V171);
# 00826	Py_XINCREF(storage_V173);
# 00827	Py_XINCREF(storage_V175);
# 00828	Py_XINCREF(storage_V177);
# 00829	Py_XINCREF(storage_V179);
# 00830	Py_XINCREF(storage_V181);
# 00831	Py_XINCREF(storage_V183);
# 00832	Py_XINCREF(storage_V185);
# 00833	Py_XINCREF(storage_V187);
# 00834	Py_XINCREF(storage_V189);
# 00835	Py_XINCREF(storage_V191);
# 00836	Py_XINCREF(storage_V193);
# 00837	Py_XINCREF(storage_V195);
# 00838	Py_XINCREF(storage_V197);
# 00839	Py_XINCREF(storage_V199);
# 00840	Py_XINCREF(storage_V201);
# 00841	Py_XINCREF(storage_V203);
# 00842	Py_XINCREF(storage_V205);
# 00843	Py_XINCREF(storage_V207);
# 00844	Py_XINCREF(storage_V209);
# 00845	Py_XINCREF(storage_V211);
# 00846	Py_XINCREF(storage_V213);
# 00847	Py_XINCREF(storage_V215);
# 00848	Py_XINCREF(storage_V217);
# 00849	Py_XINCREF(storage_V219);
# 00850	Py_XINCREF(storage_V221);
# 00851	Py_XINCREF(storage_V223);
# 00852	Py_XINCREF(storage_V225);
# 00853	Py_XINCREF(storage_V227);
# 00854	Py_XINCREF(storage_V229);
# 00855	Py_XINCREF(storage_V231);
# 00856	Py_XINCREF(storage_V233);
# 00857	Py_XINCREF(storage_V235);
# 00858	Py_XINCREF(storage_V237);
# 00859	Py_XINCREF(storage_V239);
# 00860	Py_XINCREF(storage_V241);
# 00861	Py_XINCREF(storage_V243);
# 00862	Py_XINCREF(storage_V245);
# 00863	Py_XINCREF(storage_V247);
# 00864	Py_XINCREF(storage_V249);
# 00865	Py_XINCREF(storage_V251);
# 00866	Py_XINCREF(storage_V253);
# 00867	Py_XINCREF(storage_V255);
# 00868	Py_XINCREF(storage_V257);
# 00869	Py_XINCREF(storage_V259);
# 00870	Py_XINCREF(storage_V261);
# 00871	Py_XINCREF(storage_V263);
# 00872	Py_XINCREF(storage_V265);
# 00873	Py_XINCREF(storage_V267);
# 00874	Py_XINCREF(storage_V269);
# 00875	Py_XINCREF(storage_V271);
# 00876	Py_XINCREF(storage_V273);
# 00877	Py_XINCREF(storage_V275);
# 00878	Py_XINCREF(storage_V277);
# 00879	Py_XINCREF(storage_V279);
# 00880	Py_XINCREF(storage_V281);
# 00881	Py_XINCREF(storage_V283);
# 00882	Py_XINCREF(storage_V285);
# 00883	Py_XINCREF(storage_V287);
# 00884	Py_XINCREF(storage_V289);
# 00885	Py_XINCREF(storage_V291);
# 00886	Py_XINCREF(storage_V293);
# 00887	Py_XINCREF(storage_V295);
# 00888	Py_XINCREF(storage_V297);
# 00889	Py_XINCREF(storage_V299);
# 00890	Py_XINCREF(storage_V301);
# 00891	Py_XINCREF(storage_V303);
# 00892	Py_XINCREF(storage_V305);
# 00893	Py_XINCREF(storage_V307);
# 00894	Py_XINCREF(storage_V309);
# 00895	Py_XINCREF(storage_V311);
# 00896	Py_XINCREF(storage_V313);
# 00897	Py_XINCREF(storage_V315);
# 00898	Py_XINCREF(storage_V317);
# 00899	Py_XINCREF(storage_V319);
# 00900	Py_XINCREF(storage_V321);
# 00901	Py_XINCREF(storage_V323);
# 00902	Py_XINCREF(storage_V325);
# 00903	Py_XINCREF(storage_V327);
# 00904	Py_XINCREF(storage_V329);
# 00905	Py_XINCREF(storage_V331);
# 00906	Py_XINCREF(storage_V333);
# 00907	Py_XINCREF(storage_V335);
# 00908	Py_XINCREF(storage_V337);
# 00909	Py_XINCREF(storage_V339);
# 00910	Py_XINCREF(storage_V341);
# 00911	Py_XINCREF(storage_V343);
# 00912	Py_XINCREF(storage_V345);
# 00913	Py_XINCREF(storage_V347);
# 00914	Py_XINCREF(storage_V349);
# 00915	Py_XINCREF(storage_V351);
# 00916	Py_XINCREF(storage_V353);
# 00917	Py_XINCREF(storage_V355);
# 00918	Py_XINCREF(storage_V357);
# 00919	Py_XINCREF(storage_V359);
# 00920	Py_XINCREF(storage_V361);
# 00921	Py_XINCREF(storage_V363);
# 00922	Py_XINCREF(storage_V365);
# 00923	Py_XINCREF(storage_V367);
# 00924	Py_XINCREF(storage_V369);
# 00925	Py_XINCREF(storage_V371);
# 00926	Py_XINCREF(storage_V373);
# 00927	Py_XINCREF(storage_V375);
# 00928	Py_XINCREF(storage_V377);
# 00929	Py_XINCREF(storage_V379);
# 00930	Py_XINCREF(storage_V381);
# 00931	Py_XINCREF(storage_V383);
# 00932	Py_XINCREF(storage_V385);
# 00933	Py_XINCREF(storage_V387);
# 00934	Py_XINCREF(storage_V389);
# 00935	Py_XINCREF(storage_V391);
# 00936	Py_XINCREF(storage_V393);
# 00937	Py_XINCREF(storage_V395);
# 00938	Py_XINCREF(storage_V397);
# 00939	Py_XINCREF(storage_V399);
# 00940	Py_XINCREF(storage_V401);
# 00941	Py_XINCREF(storage_V403);
# 00942	Py_XINCREF(storage_V405);
# 00943	Py_XINCREF(storage_V407);
# 00944	Py_XINCREF(storage_V409);
# 00945	Py_XINCREF(storage_V411);
# 00946	Py_XINCREF(storage_V413);
# 00947	Py_XINCREF(storage_V415);
# 00948	Py_XINCREF(storage_V417);
# 00949	Py_XINCREF(storage_V419);
# 00950	Py_XINCREF(storage_V421);
# 00951	Py_XINCREF(storage_V423);
# 00952	Py_XINCREF(storage_V425);
# 00953	Py_XINCREF(storage_V427);
# 00954	Py_XINCREF(storage_V429);
# 00955	Py_XINCREF(storage_V431);
# 00956	Py_XINCREF(storage_V433);
# 00957	Py_XINCREF(storage_V435);
# 00958	Py_XINCREF(storage_V437);
# 00959	Py_XINCREF(storage_V439);
# 00960	Py_XINCREF(storage_V441);
# 00961	Py_XINCREF(storage_V443);
# 00962	Py_XINCREF(storage_V445);
# 00963	Py_XINCREF(storage_V447);
# 00964	Py_XINCREF(storage_V449);
# 00965	Py_XINCREF(storage_V451);
# 00966	Py_XINCREF(storage_V453);
# 00967	Py_XINCREF(storage_V455);
# 00968	Py_XINCREF(storage_V457);
# 00969	Py_XINCREF(storage_V459);
# 00970	Py_XINCREF(storage_V461);
# 00971	Py_XINCREF(storage_V463);
# 00972	Py_XINCREF(storage_V465);
# 00973	Py_XINCREF(storage_V467);
# 00974	Py_XINCREF(storage_V469);
# 00975	Py_XINCREF(storage_V471);
# 00976	Py_XINCREF(storage_V473);
# 00977	Py_XINCREF(storage_V475);
# 00978	Py_XINCREF(storage_V477);
# 00979	Py_XINCREF(storage_V479);
# 00980	Py_XINCREF(storage_V481);
# 00981	Py_XINCREF(storage_V483);
# 00982	Py_XINCREF(storage_V485);
# 00983	Py_XINCREF(storage_V487);
# 00984	Py_XINCREF(storage_V489);
# 00985	Py_XINCREF(storage_V491);
# 00986	Py_XINCREF(storage_V493);
# 00987	Py_XINCREF(storage_V495);
# 00988	Py_XINCREF(storage_V497);
# 00989	Py_XINCREF(storage_V499);
# 00990	Py_XINCREF(storage_V501);
# 00991	Py_XINCREF(storage_V503);
# 00992	Py_XINCREF(storage_V505);
# 00993	Py_XINCREF(storage_V507);
# 00994	Py_XINCREF(storage_V509);
# 00995	Py_XINCREF(storage_V511);
# 00996	Py_XINCREF(storage_V513);
# 00997	Py_XINCREF(storage_V515);
# 00998	Py_XINCREF(storage_V517);
# 00999	Py_XINCREF(storage_V519);
# 01000	Py_XINCREF(storage_V521);
# 01001	Py_XINCREF(storage_V523);
# 01002	Py_XINCREF(storage_V525);
# 01003	Py_XINCREF(storage_V527);
# 01004	Py_XINCREF(storage_V529);
# 01005	Py_XINCREF(storage_V531);
# 01006	Py_XINCREF(storage_V533);
# 01007	Py_XINCREF(storage_V535);
# 01008	Py_XINCREF(storage_V537);
# 01009	Py_XINCREF(storage_V539);
# 01010	Py_XINCREF(storage_V541);
# 01011	Py_XINCREF(storage_V543);
# 01012	Py_XINCREF(storage_V545);
# 01013	Py_XINCREF(storage_V547);
# 01014	Py_XINCREF(storage_V549);
# 01015	Py_XINCREF(storage_V551);
# 01016	Py_XINCREF(storage_V553);
# 01017	Py_XINCREF(storage_V555);
# 01018	Py_XINCREF(storage_V557);
# 01019	Py_XINCREF(storage_V559);
# 01020	Py_XINCREF(storage_V561);
# 01021	Py_XINCREF(storage_V563);
# 01022	Py_XINCREF(storage_V565);
# 01023	Py_XINCREF(storage_V567);
# 01024	Py_XINCREF(storage_V569);
# 01025	Py_XINCREF(storage_V571);
# 01026	Py_XINCREF(storage_V573);
# 01027	Py_XINCREF(storage_V575);
# 01028	Py_XINCREF(storage_V577);
# 01029	Py_XINCREF(storage_V579);
# 01030	Py_XINCREF(storage_V581);
# 01031	Py_XINCREF(storage_V583);
# 01032	Py_XINCREF(storage_V585);
# 01033	Py_XINCREF(storage_V587);
# 01034	Py_XINCREF(storage_V589);
# 01035	Py_XINCREF(storage_V591);
# 01036	Py_XINCREF(storage_V593);
# 01037	Py_XINCREF(storage_V595);
# 01038	Py_XINCREF(storage_V597);
# 01039	Py_XINCREF(storage_V599);
# 01040	Py_XINCREF(storage_V601);
# 01041	Py_XINCREF(storage_V603);
# 01042	Py_XINCREF(storage_V605);
# 01043	Py_XINCREF(storage_V607);
# 01044	Py_XINCREF(storage_V609);
# 01045	Py_XINCREF(storage_V611);
# 01046	Py_XINCREF(storage_V613);
# 01047	Py_XINCREF(storage_V615);
# 01048	Py_XINCREF(storage_V617);
# 01049	Py_XINCREF(storage_V619);
# 01050	Py_XINCREF(storage_V621);
# 01051	Py_XINCREF(storage_V623);
# 01052	Py_XINCREF(storage_V625);
# 01053	Py_XINCREF(storage_V627);
# 01054	Py_XINCREF(storage_V629);
# 01055	Py_XINCREF(storage_V631);
# 01056	Py_XINCREF(storage_V633);
# 01057	Py_XINCREF(storage_V635);
# 01058	Py_XINCREF(storage_V637);
# 01059	Py_XINCREF(storage_V639);
# 01060	Py_XINCREF(storage_V641);
# 01061	Py_XINCREF(storage_V643);
# 01062	Py_XINCREF(storage_V645);
# 01063	Py_XINCREF(storage_V647);
# 01064	Py_XINCREF(storage_V649);
# 01065	Py_XINCREF(storage_V651);
# 01066	Py_XINCREF(storage_V653);
# 01067	Py_XINCREF(storage_V655);
# 01068	Py_XINCREF(storage_V657);
# 01069	Py_XINCREF(storage_V659);
# 01070	Py_XINCREF(storage_V661);
# 01071	Py_XINCREF(storage_V663);
# 01072	Py_XINCREF(storage_V665);
# 01073	Py_XINCREF(storage_V667);
# 01074	Py_XINCREF(storage_V669);
# 01075	Py_XINCREF(storage_V671);
# 01076	Py_XINCREF(storage_V673);
# 01077	Py_XINCREF(storage_V675);
# 01078	Py_XINCREF(storage_V677);
# 01079	Py_XINCREF(storage_V679);
# 01080	Py_XINCREF(storage_V681);
# 01081	Py_XINCREF(storage_V683);
# 01082	Py_XINCREF(storage_V685);
# 01083	Py_XINCREF(storage_V687);
# 01084	Py_XINCREF(storage_V689);
# 01085	Py_XINCREF(storage_V691);
# 01086	Py_XINCREF(storage_V693);
# 01087	Py_XINCREF(storage_V695);
# 01088	Py_XINCREF(storage_V697);
# 01089	Py_XINCREF(storage_V699);
# 01090	Py_XINCREF(storage_V701);
# 01091	Py_XINCREF(storage_V703);
# 01092	Py_XINCREF(storage_V705);
# 01093	Py_XINCREF(storage_V707);
# 01094	Py_XINCREF(storage_V709);
# 01095	Py_XINCREF(storage_V711);
# 01096	Py_XINCREF(storage_V713);
# 01097	Py_XINCREF(storage_V715);
# 01098	Py_XINCREF(storage_V717);
# 01099	Py_XINCREF(storage_V719);
# 01100	Py_XINCREF(storage_V721);
# 01101	Py_XINCREF(storage_V723);
# 01102	Py_XINCREF(storage_V725);
# 01103	Py_XINCREF(storage_V727);
# 01104	Py_XINCREF(storage_V729);
# 01105	Py_XINCREF(storage_V731);
# 01106	Py_XINCREF(storage_V733);
# 01107	Py_XINCREF(storage_V735);
# 01108	Py_XINCREF(storage_V737);
# 01109	Py_XINCREF(storage_V739);
# 01110	Py_XINCREF(storage_V741);
# 01111	Py_XINCREF(storage_V743);
# 01112	Py_XINCREF(storage_V745);
# 01113	Py_XINCREF(storage_V747);
# 01114	Py_XINCREF(storage_V749);
# 01115	Py_XINCREF(storage_V751);
# 01116	Py_XINCREF(storage_V753);
# 01117	Py_XINCREF(storage_V755);
# 01118	Py_XINCREF(storage_V757);
# 01119	Py_XINCREF(storage_V759);
# 01120	Py_XINCREF(storage_V761);
# 01121	Py_XINCREF(storage_V763);
# 01122	Py_XINCREF(storage_V765);
# 01123	Py_XINCREF(storage_V767);
# 01124	Py_XINCREF(storage_V769);
# 01125	Py_XINCREF(storage_V771);
# 01126	Py_XINCREF(storage_V773);
# 01127	Py_XINCREF(storage_V775);
# 01128	Py_XINCREF(storage_V777);
# 01129	Py_XINCREF(storage_V779);
# 01130	Py_XINCREF(storage_V781);
# 01131	Py_XINCREF(storage_V783);
# 01132	Py_XINCREF(storage_V785);
# 01133	Py_XINCREF(storage_V787);
# 01134	Py_XINCREF(storage_V789);
# 01135	Py_XINCREF(storage_V791);
# 01136	Py_XINCREF(storage_V793);
# 01137	Py_XINCREF(storage_V795);
# 01138	Py_XINCREF(storage_V797);
# 01139	Py_XINCREF(storage_V799);
# 01140	Py_XINCREF(storage_V801);
# 01141	Py_XINCREF(storage_V803);
# 01142	Py_XINCREF(storage_V805);
# 01143	Py_XINCREF(storage_V807);
# 01144	Py_XINCREF(storage_V809);
# 01145	Py_XINCREF(storage_V811);
# 01146	Py_XINCREF(storage_V813);
# 01147	Py_XINCREF(storage_V815);
# 01148	Py_XINCREF(storage_V817);
# 01149	Py_XINCREF(storage_V819);
# 01150	Py_XINCREF(storage_V821);
# 01151	Py_XINCREF(storage_V823);
# 01152	Py_XINCREF(storage_V825);
# 01153	Py_XINCREF(storage_V827);
# 01154	Py_XINCREF(storage_V829);
# 01155	Py_XINCREF(storage_V831);
# 01156	Py_XINCREF(storage_V833);
# 01157	Py_XINCREF(storage_V835);
# 01158	Py_XINCREF(storage_V837);
# 01159	Py_XINCREF(storage_V839);
# 01160	Py_XINCREF(storage_V841);
# 01161	Py_XINCREF(storage_V843);
# 01162	Py_XINCREF(storage_V845);
# 01163	Py_XINCREF(storage_V847);
# 01164	Py_XINCREF(storage_V849);
# 01165	Py_XINCREF(storage_V851);
# 01166	Py_XINCREF(storage_V853);
# 01167	Py_XINCREF(storage_V855);
# 01168	Py_XINCREF(storage_V857);
# 01169	Py_XINCREF(storage_V859);
# 01170	Py_XINCREF(storage_V861);
# 01171	Py_XINCREF(storage_V863);
# 01172	Py_XINCREF(storage_V865);
# 01173	Py_XINCREF(storage_V867);
# 01174	Py_XINCREF(storage_V869);
# 01175	Py_XINCREF(storage_V871);
# 01176	Py_XINCREF(storage_V873);
# 01177	Py_XINCREF(storage_V875);
# 01178	Py_XINCREF(storage_V877);
# 01179	Py_XINCREF(storage_V879);
# 01180	Py_XINCREF(storage_V881);
# 01181	Py_XINCREF(storage_V883);
# 01182	Py_XINCREF(storage_V885);
# 01183	Py_XINCREF(storage_V887);
# 01184	Py_XINCREF(storage_V889);
# 01185	Py_XINCREF(storage_V891);
# 01186	Py_XINCREF(storage_V893);
# 01187	Py_XINCREF(storage_V895);
# 01188	Py_XINCREF(storage_V897);
# 01189	Py_XINCREF(storage_V899);
# 01190	Py_XINCREF(storage_V901);
# 01191	Py_XINCREF(storage_V903);
# 01192	Py_XINCREF(storage_V905);
# 01193	Py_XINCREF(storage_V907);
# 01194	Py_XINCREF(storage_V909);
# 01195	Py_XINCREF(storage_V911);
# 01196	Py_XINCREF(storage_V913);
# 01197	Py_XINCREF(storage_V915);
# 01198	Py_XINCREF(storage_V917);
# 01199	Py_XINCREF(storage_V919);
# 01200	Py_XINCREF(storage_V921);
# 01201	Py_XINCREF(storage_V923);
# 01202	Py_XINCREF(storage_V925);
# 01203	Py_XINCREF(storage_V927);
# 01204	Py_XINCREF(storage_V929);
# 01205	Py_XINCREF(storage_V931);
# 01206	Py_XINCREF(storage_V933);
# 01207	Py_XINCREF(storage_V935);
# 01208	Py_XINCREF(storage_V937);
# 01209	Py_XINCREF(storage_V939);
# 01210	Py_XINCREF(storage_V941);
# 01211	Py_XINCREF(storage_V943);
# 01212	Py_XINCREF(storage_V945);
# 01213	Py_XINCREF(storage_V947);
# 01214	Py_XINCREF(storage_V949);
# 01215	Py_XINCREF(storage_V951);
# 01216	Py_XINCREF(storage_V953);
# 01217	Py_XINCREF(storage_V955);
# 01218	Py_XINCREF(storage_V957);
# 01219	Py_XINCREF(storage_V959);
# 01220	Py_XINCREF(storage_V961);
# 01221	Py_XINCREF(storage_V963);
# 01222	Py_XINCREF(storage_V965);
# 01223	Py_XINCREF(storage_V967);
# 01224	Py_XINCREF(storage_V969);
# 01225	Py_XINCREF(storage_V971);
# 01226	Py_XINCREF(storage_V973);
# 01227	Py_XINCREF(storage_V975);
# 01228	Py_XINCREF(storage_V977);
# 01229	Py_XINCREF(storage_V979);
# 01230	Py_XINCREF(storage_V981);
# 01231	Py_XINCREF(storage_V983);
# 01232	Py_XINCREF(storage_V985);
# 01233	Py_XINCREF(storage_V987);
# 01234	Py_XINCREF(storage_V989);
# 01235	Py_XINCREF(storage_V991);
# 01236	Py_XINCREF(storage_V993);
# 01237	Py_XINCREF(storage_V995);
# 01238	Py_XINCREF(storage_V997);
# 01239	Py_XINCREF(storage_V999);
# 01240	Py_XINCREF(storage_V1001);
# 01241	Py_XINCREF(storage_V1003);
# 01242	Py_XINCREF(storage_V1005);
# 01243	Py_XINCREF(storage_V1007);
# 01244	Py_XINCREF(storage_V1009);
# 01245	Py_XINCREF(storage_V1011);
# 01246	Py_XINCREF(storage_V1013);
# 01247	Py_XINCREF(storage_V1015);
# 01248	Py_XINCREF(storage_V1017);
# 01249	Py_XINCREF(storage_V1019);
# 01250	Py_XINCREF(storage_V1021);
# 01251	Py_XINCREF(storage_V1023);
# 01252	Py_XINCREF(storage_V1025);
# 01253	Py_XINCREF(storage_V1027);
# 01254	Py_XINCREF(storage_V1029);
# 01255	Py_XINCREF(storage_V1031);
# 01256	Py_XINCREF(storage_V1033);
# 01257	Py_XINCREF(storage_V1035);
# 01258	Py_XINCREF(storage_V1037);
# 01259	Py_XINCREF(storage_V1039);
# 01260	Py_XINCREF(storage_V1041);
# 01261	Py_XINCREF(storage_V1043);
# 01262	Py_XINCREF(storage_V1045);
# 01263	Py_XINCREF(storage_V1047);
# 01264	Py_XINCREF(storage_V1049);
# 01265	Py_XINCREF(storage_V1051);
# 01266	Py_XINCREF(storage_V1053);
# 01267	Py_XINCREF(storage_V1055);
# 01268	Py_XINCREF(storage_V1057);
# 01269	Py_XINCREF(storage_V1059);
# 01270	Py_XINCREF(storage_V1061);
# 01271	Py_XINCREF(storage_V1063);
# 01272	Py_XINCREF(storage_V1065);
# 01273	Py_XINCREF(storage_V1067);
# 01274	Py_XINCREF(storage_V1069);
# 01275	Py_XINCREF(storage_V1071);
# 01276	Py_XINCREF(storage_V1073);
# 01277	Py_XINCREF(storage_V1075);
# 01278	Py_XINCREF(storage_V1077);
# 01279	Py_XINCREF(storage_V1079);
# 01280	Py_XINCREF(storage_V1081);
# 01281	Py_XINCREF(storage_V1083);
# 01282	Py_XINCREF(storage_V1085);
# 01283	Py_XINCREF(storage_V1087);
# 01284	Py_XINCREF(storage_V1089);
# 01285	Py_XINCREF(storage_V1091);
# 01286	Py_XINCREF(storage_V1093);
# 01287	Py_XINCREF(storage_V1095);
# 01288	Py_XINCREF(storage_V1097);
# 01289	Py_XINCREF(storage_V1099);
# 01290	Py_XINCREF(storage_V1101);
# 01291	Py_XINCREF(storage_V1103);
# 01292	Py_XINCREF(storage_V1105);
# 01293	Py_XINCREF(storage_V1107);
# 01294	Py_XINCREF(storage_V1109);
# 01295	Py_XINCREF(storage_V1111);
# 01296	Py_XINCREF(storage_V1113);
# 01297	Py_XINCREF(storage_V1115);
# 01298	Py_XINCREF(storage_V1117);
# 01299	Py_XINCREF(storage_V1119);
# 01300	Py_XINCREF(storage_V1121);
# 01301	Py_XINCREF(storage_V1123);
# 01302	Py_XINCREF(storage_V1125);
# 01303	Py_XINCREF(storage_V1127);
# 01304	Py_XINCREF(storage_V1129);
# 01305	Py_XINCREF(storage_V1131);
# 01306	Py_XINCREF(storage_V1133);
# 01307	Py_XINCREF(storage_V1135);
# 01308	Py_XINCREF(storage_V1137);
# 01309	Py_XINCREF(storage_V1139);
# 01310	Py_XINCREF(storage_V1141);
# 01311	Py_XINCREF(storage_V1143);
# 01312	Py_XINCREF(storage_V1145);
# 01313	Py_XINCREF(storage_V1147);
# 01314	Py_XINCREF(storage_V1149);
# 01315	Py_XINCREF(storage_V1151);
# 01316	Py_XINCREF(storage_V1153);
# 01317	Py_XINCREF(storage_V1155);
# 01318	Py_XINCREF(storage_V1157);
# 01319	Py_XINCREF(storage_V1159);
# 01320	Py_XINCREF(storage_V1161);
# 01321	Py_XINCREF(storage_V1163);
# 01322	Py_XINCREF(storage_V1165);
# 01323	Py_XINCREF(storage_V1167);
# 01324	Py_XINCREF(storage_V1169);
# 01325	Py_XINCREF(storage_V1171);
# 01326	Py_XINCREF(storage_V1173);
# 01327	Py_XINCREF(storage_V1175);
# 01328	Py_XINCREF(storage_V1177);
# 01329	Py_XINCREF(storage_V1179);
# 01330	Py_XINCREF(storage_V1181);
# 01331	Py_XINCREF(storage_V1183);
# 01332	Py_XINCREF(storage_V1185);
# 01333	Py_XINCREF(storage_V1187);
# 01334	Py_XINCREF(storage_V1189);
# 01335	Py_XINCREF(storage_V1191);
# 01336	Py_XINCREF(storage_V1193);
# 01337	Py_XINCREF(storage_V1195);
# 01338	Py_XINCREF(storage_V1197);
# 01339	Py_XINCREF(storage_V1199);
# 01340	Py_XINCREF(storage_V1201);
# 01341	Py_XINCREF(storage_V1203);
# 01342	Py_XINCREF(storage_V1205);
# 01343	Py_XINCREF(storage_V1207);
# 01344	Py_XINCREF(storage_V1209);
# 01345	Py_XINCREF(storage_V1211);
# 01346	Py_XINCREF(storage_V1213);
# 01347	Py_XINCREF(storage_V1215);
# 01348	Py_XINCREF(storage_V1217);
# 01349	Py_XINCREF(storage_V1219);
# 01350	Py_XINCREF(storage_V1221);
# 01351	Py_XINCREF(storage_V1223);
# 01352	Py_XINCREF(storage_V1225);
# 01353	Py_XINCREF(storage_V1227);
# 01354	Py_XINCREF(storage_V1229);
# 01355	Py_XINCREF(storage_V1231);
# 01356	Py_XINCREF(storage_V1233);
# 01357	Py_XINCREF(storage_V1235);
# 01358	Py_XINCREF(storage_V1237);
# 01359	Py_XINCREF(storage_V1239);
# 01360	Py_XINCREF(storage_V1241);
# 01361	Py_XINCREF(storage_V1243);
# 01362	Py_XINCREF(storage_V1245);
# 01363	Py_XINCREF(storage_V1247);
# 01364	Py_XINCREF(storage_V1249);
# 01365	Py_XINCREF(storage_V1251);
# 01366	Py_XINCREF(storage_V1253);
# 01367	Py_XINCREF(storage_V1255);
# 01368	Py_XINCREF(storage_V1257);
# 01369	Py_XINCREF(storage_V1259);
# 01370	Py_XINCREF(storage_V1261);
# 01371	Py_XINCREF(storage_V1263);
# 01372	Py_XINCREF(storage_V1265);
# 01373	Py_XINCREF(storage_V1267);
# 01374	Py_XINCREF(storage_V1269);
# 01375	Py_XINCREF(storage_V1271);
# 01376	Py_XINCREF(storage_V1273);
# 01377	Py_XINCREF(storage_V1275);
# 01378	Py_XINCREF(storage_V1277);
# 01379	Py_XINCREF(storage_V1279);
# 01380	Py_XINCREF(storage_V1281);
# 01381	Py_XINCREF(storage_V1283);
# 01382	Py_XINCREF(storage_V1285);
# 01383	Py_XINCREF(storage_V1287);
# 01384	Py_XINCREF(storage_V1289);
# 01385	Py_XINCREF(storage_V1291);
# 01386	Py_XINCREF(storage_V1293);
# 01387	Py_XINCREF(storage_V1295);
# 01388	Py_XINCREF(storage_V1297);
# 01389	Py_XINCREF(storage_V1299);
# 01390	Py_XINCREF(storage_V1301);
# ...
# 30024	                PyErr_SetString(PyExc_ValueError, "expected an ndarray");
# 30025	                {
# 30026	        __failure = 482;
# 30027	        if (!PyErr_Occurred()) {
# 30028	            PyErr_SetString(PyExc_RuntimeError,
# 30029	                "Unexpected error in an Op's C code. "
# 30030	                "No Python exception was set.");
# 30031	            }
# 30032	        goto __label_482;}
# 30033	            }
# 30034	            // We expect NPY_BOOL
# 30035	            if (!PyArray_ISALIGNED((PyArrayObject*) py_V481)) {
# 30036	                PyArrayObject * tmp = (PyArrayObject*) py_V481;
# 30037	                PyErr_Format(PyExc_NotImplementedError,
# 30038	                             "expected an aligned array of type %ld "
# 30039	                             "(NPY_BOOL), got non-aligned array of type %ld"
# 30040	                             " with %ld dimensions, with 3 last dims "
# 30041	                             "%ld, %ld, %ld"
# 30042	                             " and 3 last strides %ld %ld, %ld.",
# 30043	                             (long int) NPY_BOOL,
# 30044	                             (long int) PyArray_TYPE((PyArrayObject*) py_V481),
# 30045	                             (long int) PyArray_NDIM(tmp),
# 30046	                             (long int) (PyArray_NDIM(tmp) >= 3 ?
# 30047	            PyArray_DIMS(tmp)[PyArray_NDIM(tmp)-3] : -1),
# 30048	                             (long int) (PyArray_NDIM(tmp) >= 2 ?
# 30049	            PyArray_DIMS(tmp)[PyArray_NDIM(tmp)-2] : -1),
# 30050	                             (long int) (PyArray_NDIM(tmp) >= 1 ?
# 30051	            PyArray_DIMS(tmp)[PyArray_NDIM(tmp)-1] : -1),
# 30052	                             (long int) (PyArray_NDIM(tmp) >= 3 ?
# 30053	            PyArray_STRIDES(tmp)[PyArray_NDIM(tmp)-3] : -1),
# 30054	                             (long int) (PyArray_NDIM(tmp) >= 2 ?
# 30055	            PyArray_STRIDES(tmp)[PyArray_NDIM(tmp)-2] : -1),
# 30056	                             (long int) (PyArray_NDIM(tmp) >= 1 ?
# 30057	            PyArray_STRIDES(tmp)[PyArray_NDIM(tmp)-1] : -1)
# 30058	            );
# 30059	                {
# 30060	        __failure = 482;
# 30061	        if (!PyErr_Occurred()) {
# 30062	            PyErr_SetString(PyExc_RuntimeError,
# 30063	                "Unexpected error in an Op's C code. "
# 30064	                "No Python exception was set.");
# 30065	            }
# 30066	        goto __label_482;}
# 30067	            }
# 30068	            // This is a TypeError to be consistent with DEBUG_MODE
# 30069	            // Note: DEBUG_MODE also tells the name of the container
# 30070	            if (PyArray_TYPE((PyArrayObject*) py_V481) != NPY_BOOL) {
# 30071	                PyErr_Format(PyExc_TypeError,
# 30072	                             "expected type_num %d (NPY_BOOL) got %d",
# 30073	                             NPY_BOOL, PyArray_TYPE((PyArrayObject*) py_V481));
# 30074	                {
# 30075	        __failure = 482;
# 30076	        if (!PyErr_Occurred()) {
# 30077	            PyErr_SetString(PyExc_RuntimeError,
# 30078	                "Unexpected error in an Op's C code. "
# 30079	                "No Python exception was set.");
# 30080	            }
# 30081	        goto __label_482;}
# 30082	            }
# 30083
# 30084	        V481 = (PyArrayObject*)(py_V481);
# 30085	        Py_XINCREF(V481);
# 30086
# 30087	{
# 30088
# 30089	    py_V483 = PyList_GET_ITEM(storage_V483, 0);
# 30090	    {Py_XINCREF(py_V483);}
# 30091
# 30092	            V483 = NULL;
# 30093	            if (py_V483 == Py_None) {
# 30094	                // We can either fail here or set V483 to NULL and rely on Ops
# 30095	                // using tensors to handle the NULL case, but if they fail to do so
# 30096	                // they'll end up with nasty segfaults, so this is public service.
# 30097	                PyErr_SetString(PyExc_ValueError, "expected an ndarray, not None");
# 30098	                {
# 30099	        __failure = 484;
# 30100	        if (!PyErr_Occurred()) {
# 30101	            PyErr_SetString(PyExc_RuntimeError,
# 30102	                "Unexpected error in an Op's C code. "
# 30103	                "No Python exception was set.");
# 30104	            }
# 30105	        goto __label_484;}
# 30106	            }
# 30107	            if (!PyArray_Check(py_V483)) {
# 30108	                PyErr_SetString(PyExc_ValueError, "expected an ndarray");
# 30109	                {
# 30110	        __failure = 484;
# 30111	        if (!PyErr_Occurred()) {
# 30112	            PyErr_SetString(PyExc_RuntimeError,
# 30113	                "Unexpected error in an Op's C code. "
# 30114	                "No Python exception was set.");
# 30115	            }
# 30116	        goto __label_484;}
# 30117	            }
# 30118	            // We expect NPY_FLOAT64
# 30119	            if (!PyArray_ISALIGNED((PyArrayObject*) py_V483)) {
# 30120	                PyArrayObject * tmp = (PyArrayObject*) py_V483;
# 30121	                PyErr_Format(PyExc_NotImplementedError,
# 30122	                             "expected an aligned array of type %ld "
# 30123	                             "(NPY_FLOAT64), got non-aligned array of type %ld"
# 30124	                             " with %ld dimensions, with 3 last dims "
# 30125	                             "%ld, %ld, %ld"
# 30126	                             " and 3 last strides %ld %ld, %ld.",
# 30127	                             (long int) NPY_FLOAT64,
# 30128	                             (long int) PyArray_TYPE((PyArrayObject*) py_V483),
# 30129	                             (long int) PyArray_NDIM(tmp),
# 30130	                             (long int) (PyArray_NDIM(tmp) >= 3 ?
# 30131	            PyArray_DIMS(tmp)[PyArray_NDIM(tmp)-3] : -1),
# 30132	                             (long int) (PyArray_NDIM(tmp) >= 2 ?
# 30133	            PyArray_DIMS(tmp)[PyArray_NDIM(tmp)-2] : -1),
# 30134	                             (long int) (PyArray_NDIM(tmp) >= 1 ?
# 30135	            PyArray_DIMS(tmp)[PyArray_NDIM(tmp)-1] : -1),
# 30136	                             (long int) (PyArray_NDIM(tmp) >= 3 ?
# 30137	            PyArray_STRIDES(tmp)[PyArray_NDIM(tmp)-3] : -1),
# 30138	                             (long int) (PyArray_NDIM(tmp) >= 2 ?
# 30139	            PyArray_STRIDES(tmp)[PyArray_NDIM(tmp)-2] : -1),
# 30140	                             (long int) (PyArray_NDIM(tmp) >= 1 ?
# 30141	            PyArray_STRIDES(tmp)[PyArray_NDIM(tmp)-1] : -1)
# 30142	            );
# 30143	                {
# 30144	        __failure = 484;
# 30145	        if (!PyErr_Occurred()) {
# 30146	            PyErr_SetString(PyExc_RuntimeError,
# 30147	                "Unexpected error in an Op's C code. "
# 30148	                "No Python exception was set.");
# 30149	            }
# 30150	        goto __label_484;}
# 30151	            }
# 30152	            // This is a TypeError to be consistent with DEBUG_MODE
# 30153	            // Note: DEBUG_MODE also tells the name of the container
# 30154	            if (PyArray_TYPE((PyArrayObject*) py_V483) != NPY_FLOAT64) {
# 30155	                PyErr_Format(PyExc_TypeError,
# 30156	                             "expected type_num %d (NPY_FLOAT64) got %d",
# 30157	                             NPY_FLOAT64, PyArray_TYPE((PyArrayObject*) py_V483));
# 30158	                {
# 30159	        __failure = 484;
# 30160	        if (!PyErr_Occurred()) {
# 30161	            PyErr_SetString(PyExc_RuntimeError,
# 30162	                "Unexpected error in an Op's C code. "
# 30163	                "No Python exception was set.");
# 30164	            }
# 30165	        goto __label_484;}
# 30166	            }
# 30167
# 30168	        V483 = (PyArrayObject*)(py_V483);
# 30169	        Py_XINCREF(V483);
# 30170
# 30171	{
# 30172
# 30173	    py_V485 = PyList_GET_ITEM(storage_V485, 0);
# 30174	    {Py_XINCREF(py_V485);}
# 30175
# 30176	            V485 = NULL;
# 30177	            if (py_V485 == Py_None) {
# 30178	                // We can either fail here or set V485 to NULL and rely on Ops
# 30179	                // using tensors to handle the NULL case, but if they fail to do so
# 30180	                // they'll end up with nasty segfaults, so this is public service.
# 30181	                PyErr_SetString(PyExc_ValueError, "expected an ndarray, not None");
# 30182	                {
# 30183	        __failure = 486;
# 30184	        if (!PyErr_Occurred()) {
# 30185	            PyErr_SetString(PyExc_RuntimeError,
# 30186	                "Unexpected error in an Op's C code. "
# 30187	                "No Python exception was set.");
# 30188	            }
# 30189	        goto __label_486;}
# 30190	            }
# 30191	            if (!PyArray_Check(py_V485)) {
# 30192	                PyErr_SetString(PyExc_ValueError, "expected an ndarray");
# 30193	                {
# 30194	        __failure = 486;
# 30195	        if (!PyErr_Occurred()) {
# 30196	            PyErr_SetString(PyExc_RuntimeError,
# 30197	                "Unexpected error in an Op's C code. "
# 30198	                "No Python exception was set.");
# 30199	            }
# 30200	        goto __label_486;}
# 30201	            }
# 30202	            // We expect NPY_FLOAT64
# 30203	            if (!PyArray_ISALIGNED((PyArrayObject*) py_V485)) {
# 30204	                PyArrayObject * tmp = (PyArrayObject*) py_V485;
# 30205	                PyErr_Format(PyExc_NotImplementedError,
# 30206	                             "expected an aligned array of type %ld "
# 30207	                             "(NPY_FLOAT64), got non-aligned array of type %ld"
# 30208	                             " with %ld dimensions, with 3 last dims "
# 30209	                             "%ld, %ld, %ld"
# 30210	                             " and 3 last strides %ld %ld, %ld.",
# 30211	                             (long int) NPY_FLOAT64,
# 30212	                             (long int) PyArray_TYPE((PyArrayObject*) py_V485),
# 30213	                             (long int) PyArray_NDIM(tmp),
# 30214	                             (long int) (PyArray_NDIM(tmp) >= 3 ?
# 30215	            PyArray_DIMS(tmp)[PyArray_NDIM(tmp)-3] : -1),
# 30216	                             (long int) (PyArray_NDIM(tmp) >= 2 ?
# 30217	            PyArray_DIMS(tmp)[PyArray_NDIM(tmp)-2] : -1),
# 30218	                             (long int) (PyArray_NDIM(tmp) >= 1 ?
# 30219	            PyArray_DIMS(tmp)[PyArray_NDIM(tmp)-1] : -1),
# 30220	                             (long int) (PyArray_NDIM(tmp) >= 3 ?
# 30221	            PyArray_STRIDES(tmp)[PyArray_NDIM(tmp)-3] : -1),
# 30222	                             (long int) (PyArray_NDIM(tmp) >= 2 ?
# 30223	            PyArray_STRIDES(tmp)[PyArray_NDIM(tmp)-2] : -1),
# 30224	                             (long int) (PyArray_NDIM(tmp) >= 1 ?
# 30225	            PyArray_STRIDES(tmp)[PyArray_NDIM(tmp)-1] : -1)
# 30226	            );
# 30227	                {
# 30228	        __failure = 486;
# 30229	        if (!PyErr_Occurred()) {
# 30230	            PyErr_SetString(PyExc_RuntimeError,
# 30231	                "Unexpected error in an Op's C code. "
# 30232	                "No Python exception was set.");
# 30233	            }
# 30234	        goto __label_486;}
# 30235	            }
# 30236	            // This is a TypeError to be consistent with DEBUG_MODE
# 30237	            // Note: DEBUG_MODE also tells the name of the container
# 30238	            if (PyArray_TYPE((PyArrayObject*) py_V485) != NPY_FLOAT64) {
# 30239	                PyErr_Format(PyExc_TypeError,
# 30240	                             "expected type_num %d (NPY_FLOAT64) got %d",
# 30241	                             NPY_FLOAT64, PyArray_TYPE((PyArrayObject*) py_V485));
# 30242	                {
# 30243	        __failure = 486;
# 30244	        if (!PyErr_Occurred()) {
# 30245	            PyErr_SetString(PyExc_RuntimeError,
# 30246	                "Unexpected error in an Op's C code. "
# 30247	                "No Python exception was set.");
# 30248	            }
# 30249	        goto __label_486;}
# 30250	            }
# 30251
# 30252	        V485 = (PyArrayObject*)(py_V485);
# 30253	        Py_XINCREF(V485);
# 30254
# 30255	{
# 30256
# 30257	    py_V487 = PyList_GET_ITEM(storage_V487, 0);
# 30258	    {Py_XINCREF(py_V487);}
# 30259
# 30260	            V487 = NULL;
# 30261	            if (py_V487 == Py_None) {
# 30262	                // We can either fail here or set V487 to NULL and rely on Ops
# 30263	                // using tensors to handle the NULL case, but if they fail to do so
# 30264	                // they'll end up with nasty segfaults, so this is public service.
# 30265	                PyErr_SetString(PyExc_ValueError, "expected an ndarray, not None");
# 30266	                {
# 30267	        __failure = 488;
# 30268	        if (!PyErr_Occurred()) {
# 30269	            PyErr_SetString(PyExc_RuntimeError,
# 30270	                "Unexpected error in an Op's C code. "
# 30271	                "No Python exception was set.");
# 30272	            }
# 30273	        goto __label_488;}
# 30274	            }
# 30275	            if (!PyArray_Check(py_V487)) {
# 30276	                PyErr_SetString(PyExc_ValueError, "expected an ndarray");
# 30277	                {
# 30278	        __failure = 488;
# 30279	        if (!PyErr_Occurred()) {
# 30280	            PyErr_SetString(PyExc_RuntimeError,
# 30281	                "Unexpected error in an Op's C code. "
# 30282	                "No Python exception was set.");
# 30283	            }
# 30284	        goto __label_488;}
# 30285	            }
# 30286	            // We expect NPY_BOOL
# 30287	            if (!PyArray_ISALIGNED((PyArrayObject*) py_V487)) {
# 30288	                PyArrayObject * tmp = (PyArrayObject*) py_V487;
# 30289	                PyErr_Format(PyExc_NotImplementedError,
# 30290	                             "expected an aligned array of type %ld "
# 30291	                             "(NPY_BOOL), got non-aligned array of type %ld"
# 30292	                             " with %ld dimensions, with 3 last dims "
# 30293	                             "%ld, %ld, %ld"
# 30294	                             " and 3 last strides %ld %ld, %ld.",
# 30295	                             (long int) NPY_BOOL,
# 30296	                             (long int) PyArray_TYPE((PyArrayObject*) py_V487),
# 30297	                             (long int) PyArray_NDIM(tmp),
# 30298	                             (long int) (PyArray_NDIM(tmp) >= 3 ?
# 30299	            PyArray_DIMS(tmp)[PyArray_NDIM(tmp)-3] : -1),
# 30300	                             (long int) (PyArray_NDIM(tmp) >= 2 ?
# 30301	            PyArray_DIMS(tmp)[PyArray_NDIM(tmp)-2] : -1),
# 30302	                             (long int) (PyArray_NDIM(tmp) >= 1 ?
# 30303	            PyArray_DIMS(tmp)[PyArray_NDIM(tmp)-1] : -1),
# 30304	                             (long int) (PyArray_NDIM(tmp) >= 3 ?
# 30305	            PyArray_STRIDES(tmp)[PyArray_NDIM(tmp)-3] : -1),
# 30306	                             (long int) (PyArray_NDIM(tmp) >= 2 ?
# 30307	            PyArray_STRIDES(tmp)[PyArray_NDIM(tmp)-2] : -1),
# 30308	                             (long int) (PyArray_NDIM(tmp) >= 1 ?
# 30309	            PyArray_STRIDES(tmp)[PyArray_NDIM(tmp)-1] : -1)
# 30310	            );
# 30311	                {
# 30312	        __failure = 488;
# 30313	        if (!PyErr_Occurred()) {
# 30314	            PyErr_SetString(PyExc_RuntimeError,
# 30315	                "Unexpected error in an Op's C code. "
# 30316	                "No Python exception was set.");
# 30317	            }
# 30318	        goto __label_488;}
# 30319	            }
# 30320	            // This is a TypeError to be consistent with DEBUG_MODE
# 30321	            // Note: DEBUG_MODE also tells the name of the container
# 30322	            if (PyArray_TYPE((PyArrayObject*) py_V487) != NPY_BOOL) {
# 30323	                PyErr_Format(PyExc_TypeError,
# 30324	                             "expected type_num %d (NPY_BOOL) got %d",
# 30325	                             NPY_BOOL, PyArray_TYPE((PyArrayObject*) py_V487));
# 30326	                {
# 30327	        __failure = 488;
# 30328	        if (!PyErr_Occurred()) {
# 30329	            PyErr_SetString(PyExc_RuntimeError,
# 30330	                "Unexpected error in an Op's C code. "
# 30331	                "No Python exception was set.");
# 30332	            }
# 30333	        goto __label_488;}
# 30334	            }
# 30335
# 30336	        V487 = (PyArrayObject*)(py_V487);
# 30337	        Py_XINCREF(V487);
