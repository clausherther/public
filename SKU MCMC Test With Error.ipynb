# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import pymc3 as pm
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy.stats
import seaborn as sns

# %matplotlib inline
# Out:
# Couldn't import dot_parser, loading of dot files will not be possible.

# %%
def get_skus(n):
    r_skus = np.arange(1, n+1,1)
    sku_perc = np.random.dirichlet(np.ones(len(r_skus))*1000.,size=1)
    return pd.DataFrame(list(zip(r_skus, sku_perc[0])), columns=['sku', 'sku_percent'])

# %%
# Let's make a few SKUs...somewhere above 20 sku, the sampling below will fail
df_skus = get_skus(56)
df_skus.tail()
# Out:
#     sku  sku_percent
# 51   52     0.017560
# 52   53     0.018524
# 53   54     0.017628
# 54   55     0.017804
# 55   56     0.016850

# %%
n_samples, n_burn = 1000, 2000

# historically, we observe that this style is bought 15% of the time
style_percent_obs = 0.15

# we plan 1000 units of this style for next year
style_demand_planned = 1000

with pm.Model() as model:

    # we'll model the style distribution as a uniform prior
    style_percent = pm.Uniform('style_percent', 0, 1, testval=style_percent_obs)
    style_demand = pm.Deterministic('style_demand', style_demand_planned * style_percent)
    
    # then for every sku, we model the sku distribution as a uniform prior and
    # we want to determine the distribution of the resulting sku demand to be planned in units

    for _, sku in df_skus.iterrows():
        
        i = sku['sku']
        sku_perc = pm.Uniform(f'sku_percent_{i}', 0, 1, testval=sku['sku_percent'])
        sku_demand = pm.Deterministic(f'sku_demand_{i}', style_demand * sku_perc)

        sku_planned = pm.Poisson(f'sku_planned_{i}', mu=sku_demand, observed=np.ceil(style_demand_planned * sku['sku_percent']))

    trace = pm.sample(n_samples, tune=n_burn, random_seed=42, progressbar=True)
# Out:
# INFO (theano.gof.compilelock): Waiting for existing lock by process '62440' (I am process '62775')
# INFO (theano.gof.compilelock): To manually release the lock, delete /Users/claus/.theano/compiledir_Darwin-16.7.0-x86_64-i386-64bit-i386-3.6.2-64/lock_dir
# Auto-assigning NUTS sampler...
# Initializing NUTS using ADVI...
# ===============================
# 00001	#include <Python.h>
# 00002	#include <iostream>
# 00003	#include "theano_mod_helper.h"
# 00004	#include <math.h>
# 00005	#include <numpy/arrayobject.h>
# 00006	#include <numpy/arrayscalars.h>
# 00007	#include <vector>
# 00008	#include <algorithm>
# 00009	//////////////////////
# 00010	////  Support Code
# 00011	//////////////////////
# 00012
# 00013	    namespace {
# 00014	    struct __struct_compiled_op_m8c3e8e4c4477ca5f184195f00826ad83 {
# 00015	        PyObject* __ERROR;
# 00016
# 00017	        PyObject* storage_V3;
# 00018	PyObject* storage_V5;
# 00019	PyObject* storage_V7;
# 00020	PyObject* storage_V9;
# 00021	PyObject* storage_V11;
# 00022	PyObject* storage_V13;
# 00023	PyObject* storage_V15;
# 00024	PyObject* storage_V17;
# 00025	PyObject* storage_V19;
# 00026	PyObject* storage_V21;
# 00027	PyObject* storage_V23;
# 00028	PyObject* storage_V25;
# 00029	PyObject* storage_V27;
# 00030	PyObject* storage_V29;
# 00031	PyObject* storage_V31;
# 00032	PyObject* storage_V33;
# 00033	PyObject* storage_V35;
# 00034	PyObject* storage_V37;
# 00035	PyObject* storage_V39;
# 00036	PyObject* storage_V41;
# 00037	PyObject* storage_V43;
# 00038	PyObject* storage_V45;
# 00039	PyObject* storage_V47;
# 00040	PyObject* storage_V49;
# 00041	PyObject* storage_V51;
# 00042	PyObject* storage_V53;
# 00043	PyObject* storage_V55;
# 00044	PyObject* storage_V57;
# 00045	PyObject* storage_V59;
# 00046	PyObject* storage_V61;
# 00047	PyObject* storage_V63;
# 00048	PyObject* storage_V65;
# 00049	PyObject* storage_V67;
# 00050	PyObject* storage_V69;
# 00051	PyObject* storage_V71;
# 00052	PyObject* storage_V73;
# 00053	PyObject* storage_V75;
# 00054	PyObject* storage_V77;
# 00055	PyObject* storage_V79;
# 00056	PyObject* storage_V81;
# 00057	PyObject* storage_V83;
# 00058	PyObject* storage_V85;
# 00059	PyObject* storage_V87;
# 00060	PyObject* storage_V89;
# 00061	PyObject* storage_V91;
# 00062	PyObject* storage_V93;
# 00063	PyObject* storage_V95;
# 00064	PyObject* storage_V97;
# 00065	PyObject* storage_V99;
# 00066	PyObject* storage_V101;
# 00067	PyObject* storage_V103;
# 00068	PyObject* storage_V105;
# 00069	PyObject* storage_V107;
# 00070	PyObject* storage_V109;
# 00071	PyObject* storage_V111;
# 00072	PyObject* storage_V113;
# 00073	PyObject* storage_V115;
# 00074	PyObject* storage_V117;
# 00075	PyObject* storage_V119;
# 00076	PyObject* storage_V121;
# 00077	PyObject* storage_V123;
# 00078	PyObject* storage_V125;
# 00079	PyObject* storage_V127;
# 00080	PyObject* storage_V129;
# 00081	PyObject* storage_V131;
# 00082	PyObject* storage_V133;
# 00083	PyObject* storage_V135;
# 00084	PyObject* storage_V137;
# 00085	PyObject* storage_V139;
# 00086	PyObject* storage_V141;
# 00087	PyObject* storage_V143;
# 00088	PyObject* storage_V145;
# 00089	PyObject* storage_V147;
# 00090	PyObject* storage_V149;
# 00091	PyObject* storage_V151;
# 00092	PyObject* storage_V153;
# 00093	PyObject* storage_V155;
# 00094	PyObject* storage_V157;
# 00095	PyObject* storage_V159;
# 00096	PyObject* storage_V161;
# 00097	PyObject* storage_V163;
# 00098	PyObject* storage_V165;
# 00099	PyObject* storage_V167;
# 00100	PyObject* storage_V169;
# 00101	PyObject* storage_V171;
# 00102	PyObject* storage_V173;
# 00103	PyObject* storage_V175;
# 00104	PyObject* storage_V177;
# 00105	PyObject* storage_V179;
# 00106	PyObject* storage_V181;
# 00107	PyObject* storage_V183;
# 00108	PyObject* storage_V185;
# 00109	PyObject* storage_V187;
# 00110	PyObject* storage_V189;
# 00111	PyObject* storage_V191;
# 00112	PyObject* storage_V193;
# 00113	PyObject* storage_V195;
# 00114	PyObject* storage_V197;
# 00115	PyObject* storage_V199;
# 00116	PyObject* storage_V201;
# 00117	PyObject* storage_V203;
# 00118	PyObject* storage_V205;
# 00119	PyObject* storage_V207;
# 00120	PyObject* storage_V209;
# 00121	PyObject* storage_V211;
# 00122	PyObject* storage_V213;
# 00123	PyObject* storage_V215;
# 00124	PyObject* storage_V217;
# 00125	PyObject* storage_V219;
# 00126	PyObject* storage_V221;
# 00127	PyObject* storage_V223;
# 00128	PyObject* storage_V225;
# 00129	PyObject* storage_V227;
# 00130	PyObject* storage_V229;
# 00131	PyObject* storage_V231;
# 00132	PyObject* storage_V233;
# 00133	PyObject* storage_V235;
# 00134	PyObject* storage_V237;
# 00135	PyObject* storage_V239;
# 00136	PyObject* storage_V241;
# 00137	PyObject* storage_V243;
# 00138	PyObject* storage_V245;
# 00139	PyObject* storage_V247;
# 00140	PyObject* storage_V249;
# 00141	PyObject* storage_V251;
# 00142	PyObject* storage_V253;
# 00143	PyObject* storage_V255;
# 00144	PyObject* storage_V257;
# 00145	PyObject* storage_V259;
# 00146	PyObject* storage_V261;
# 00147	PyObject* storage_V263;
# 00148	PyObject* storage_V265;
# 00149	PyObject* storage_V267;
# 00150	PyObject* storage_V269;
# 00151	PyObject* storage_V271;
# 00152	PyObject* storage_V273;
# 00153	PyObject* storage_V275;
# 00154	PyObject* storage_V277;
# 00155	PyObject* storage_V279;
# 00156	PyObject* storage_V281;
# 00157	PyObject* storage_V283;
# 00158	PyObject* storage_V285;
# 00159	PyObject* storage_V287;
# 00160	PyObject* storage_V289;
# 00161	PyObject* storage_V291;
# 00162	PyObject* storage_V293;
# 00163	PyObject* storage_V295;
# 00164	PyObject* storage_V297;
# 00165	PyObject* storage_V299;
# 00166	PyObject* storage_V301;
# 00167	PyObject* storage_V303;
# 00168	PyObject* storage_V305;
# 00169	PyObject* storage_V307;
# 00170	PyObject* storage_V309;
# 00171	PyObject* storage_V311;
# 00172	PyObject* storage_V313;
# 00173	PyObject* storage_V315;
# 00174	PyObject* storage_V317;
# 00175	PyObject* storage_V319;
# 00176	PyObject* storage_V321;
# 00177	PyObject* storage_V323;
# 00178	PyObject* storage_V325;
# 00179	PyObject* storage_V327;
# 00180	PyObject* storage_V329;
# 00181	PyObject* storage_V331;
# 00182	PyObject* storage_V333;
# 00183	PyObject* storage_V335;
# 00184	PyObject* storage_V337;
# 00185	PyObject* storage_V339;
# 00186	PyObject* storage_V341;
# 00187	PyObject* storage_V343;
# 00188	PyObject* storage_V345;
# 00189	PyObject* storage_V347;
# 00190	PyObject* storage_V349;
# 00191	PyObject* storage_V351;
# 00192	PyObject* storage_V353;
# 00193	PyObject* storage_V355;
# 00194	PyObject* storage_V357;
# 00195	PyObject* storage_V359;
# 00196	PyObject* storage_V361;
# 00197	PyObject* storage_V363;
# 00198	PyObject* storage_V365;
# 00199	PyObject* storage_V367;
# 00200	PyObject* storage_V369;
# 00201	PyObject* storage_V371;
# 00202	PyObject* storage_V373;
# 00203	PyObject* storage_V375;
# 00204	PyObject* storage_V377;
# 00205	PyObject* storage_V379;
# 00206	PyObject* storage_V381;
# 00207	PyObject* storage_V383;
# 00208	PyObject* storage_V385;
# 00209	PyObject* storage_V387;
# 00210	PyObject* storage_V389;
# 00211	PyObject* storage_V391;
# 00212	PyObject* storage_V393;
# 00213	PyObject* storage_V395;
# 00214	PyObject* storage_V397;
# 00215	PyObject* storage_V399;
# 00216	PyObject* storage_V401;
# 00217	PyObject* storage_V403;
# 00218	PyObject* storage_V405;
# 00219	PyObject* storage_V407;
# 00220	PyObject* storage_V409;
# 00221	PyObject* storage_V411;
# 00222	PyObject* storage_V413;
# 00223	PyObject* storage_V415;
# 00224	PyObject* storage_V417;
# 00225	PyObject* storage_V419;
# 00226	PyObject* storage_V421;
# 00227	PyObject* storage_V423;
# 00228	PyObject* storage_V425;
# 00229	PyObject* storage_V427;
# 00230	PyObject* storage_V429;
# 00231	PyObject* storage_V431;
# 00232	PyObject* storage_V433;
# 00233	PyObject* storage_V435;
# 00234	PyObject* storage_V437;
# 00235	PyObject* storage_V439;
# 00236	PyObject* storage_V441;
# 00237	PyObject* storage_V443;
# 00238	PyObject* storage_V445;
# 00239	PyObject* storage_V447;
# 00240	PyObject* storage_V449;
# 00241	PyObject* storage_V451;
# 00242	PyObject* storage_V453;
# 00243	PyObject* storage_V455;
# 00244	PyObject* storage_V457;
# 00245	PyObject* storage_V459;
# 00246	PyObject* storage_V461;
# 00247	PyObject* storage_V463;
# 00248	PyObject* storage_V465;
# 00249	PyObject* storage_V467;
# 00250	PyObject* storage_V469;
# 00251	PyObject* storage_V471;
# 00252	PyObject* storage_V473;
# 00253	PyObject* storage_V475;
# 00254	PyObject* storage_V477;
# 00255	PyObject* storage_V479;
# 00256	PyObject* storage_V481;
# 00257	PyObject* storage_V483;
# 00258	PyObject* storage_V485;
# 00259	PyObject* storage_V487;
# 00260	PyObject* storage_V489;
# 00261	PyObject* storage_V491;
# 00262	PyObject* storage_V493;
# 00263	PyObject* storage_V495;
# 00264	PyObject* storage_V497;
# 00265	PyObject* storage_V499;
# 00266	PyObject* storage_V501;
# 00267	PyObject* storage_V503;
# 00268	PyObject* storage_V505;
# 00269	PyObject* storage_V507;
# 00270	PyObject* storage_V509;
# 00271	PyObject* storage_V511;
# 00272	PyObject* storage_V513;
# 00273	PyObject* storage_V515;
# 00274	PyObject* storage_V517;
# 00275	PyObject* storage_V519;
# 00276	PyObject* storage_V521;
# 00277	PyObject* storage_V523;
# 00278	PyObject* storage_V525;
# 00279	PyObject* storage_V527;
# 00280	PyObject* storage_V529;
# 00281	PyObject* storage_V531;
# 00282	PyObject* storage_V533;
# 00283	PyObject* storage_V535;
# 00284	PyObject* storage_V537;
# 00285	PyObject* storage_V539;
# 00286	PyObject* storage_V541;
# 00287	PyObject* storage_V543;
# 00288	PyObject* storage_V545;
# 00289	PyObject* storage_V547;
# 00290	PyObject* storage_V549;
# 00291	PyObject* storage_V551;
# 00292	PyObject* storage_V553;
# 00293	PyObject* storage_V555;
# 00294	PyObject* storage_V557;
# 00295	PyObject* storage_V559;
# 00296	PyObject* storage_V561;
# 00297	PyObject* storage_V563;
# 00298	PyObject* storage_V565;
# 00299	PyObject* storage_V567;
# 00300	PyObject* storage_V569;
# 00301	PyObject* storage_V571;
# 00302	PyObject* storage_V573;
# 00303	PyObject* storage_V575;
# 00304	PyObject* storage_V577;
# 00305	PyObject* storage_V579;
# 00306	PyObject* storage_V581;
# 00307	PyObject* storage_V583;
# 00308	PyObject* storage_V585;
# 00309	PyObject* storage_V587;
# 00310	PyObject* storage_V589;
# 00311	PyObject* storage_V591;
# 00312	PyObject* storage_V593;
# 00313	PyObject* storage_V595;
# 00314	PyObject* storage_V597;
# 00315	PyObject* storage_V599;
# 00316	PyObject* storage_V601;
# 00317	PyObject* storage_V603;
# 00318	PyObject* storage_V605;
# 00319	PyObject* storage_V607;
# 00320	PyObject* storage_V609;
# 00321	PyObject* storage_V611;
# 00322	PyObject* storage_V613;
# 00323	PyObject* storage_V615;
# 00324	PyObject* storage_V617;
# 00325	PyObject* storage_V619;
# 00326	PyObject* storage_V621;
# 00327	PyObject* storage_V623;
# 00328	PyObject* storage_V625;
# 00329	PyObject* storage_V627;
# 00330	PyObject* storage_V629;
# 00331	PyObject* storage_V631;
# 00332	PyObject* storage_V633;
# 00333	PyObject* storage_V635;
# 00334	PyObject* storage_V637;
# 00335	PyObject* storage_V639;
# 00336	PyObject* storage_V641;
# 00337	PyObject* storage_V643;
# 00338	PyObject* storage_V645;
# 00339	PyObject* storage_V647;
# 00340	PyObject* storage_V649;
# 00341	PyObject* storage_V651;
# 00342	PyObject* storage_V653;
# 00343	PyObject* storage_V655;
# 00344	PyObject* storage_V657;
# 00345	PyObject* storage_V659;
# 00346	PyObject* storage_V661;
# 00347	PyObject* storage_V663;
# 00348	PyObject* storage_V665;
# 00349	PyObject* storage_V667;
# 00350	PyObject* storage_V669;
# 00351	PyObject* storage_V671;
# 00352	PyObject* storage_V673;
# 00353	PyObject* storage_V675;
# 00354	PyObject* storage_V677;
# 00355	PyObject* storage_V679;
# 00356	PyObject* storage_V681;
# 00357	PyObject* storage_V683;
# 00358	PyObject* storage_V685;
# 00359	PyObject* storage_V687;
# 00360	PyObject* storage_V689;
# 00361	PyObject* storage_V691;
# 00362	PyObject* storage_V693;
# 00363	PyObject* storage_V695;
# 00364	PyObject* storage_V697;
# 00365	PyObject* storage_V699;
# 00366	PyObject* storage_V701;
# 00367	PyObject* storage_V703;
# 00368	PyObject* storage_V705;
# 00369	PyObject* storage_V707;
# 00370	PyObject* storage_V1;
# 00371
# 00372
# 00373	        __struct_compiled_op_m8c3e8e4c4477ca5f184195f00826ad83() {
# 00374	            // This is only somewhat safe because we:
# 00375	            //  1) Are not a virtual class
# 00376	            //  2) Do not use any virtual classes in the members
# 00377	            //  3) Deal with mostly POD and pointers
# 00378
# 00379	            // If this changes, we would have to revise this, but for
# 00380	            // now I am tired of chasing segfaults because
# 00381	            // initialization code had an error and some pointer has
# 00382	            // a junk value.
# 00383	            memset(this, 0, sizeof(*this));
# 00384	        }
# 00385	        ~__struct_compiled_op_m8c3e8e4c4477ca5f184195f00826ad83(void) {
# 00386	            cleanup();
# 00387	        }
# 00388
# 00389	        int init(PyObject* __ERROR, PyObject* storage_V3, PyObject* storage_V5, PyObject* storage_V7, PyObject* storage_V9, PyObject* storage_V11, PyObject* storage_V13, PyObject* storage_V15, PyObject* storage_V17, PyObject* storage_V19, PyObject* storage_V21, PyObject* storage_V23, PyObject* storage_V25, PyObject* storage_V27, PyObject* storage_V29, PyObject* storage_V31, PyObject* storage_V33, PyObject* storage_V35, PyObject* storage_V37, PyObject* storage_V39, PyObject* storage_V41, PyObject* storage_V43, PyObject* storage_V45, PyObject* storage_V47, PyObject* storage_V49, PyObject* storage_V51, PyObject* storage_V53, PyObject* storage_V55, PyObject* storage_V57, PyObject* storage_V59, PyObject* storage_V61, PyObject* storage_V63, PyObject* storage_V65, PyObject* storage_V67, PyObject* storage_V69, PyObject* storage_V71, PyObject* storage_V73, PyObject* storage_V75, PyObject* storage_V77, PyObject* storage_V79, PyObject* storage_V81, PyObject* storage_V83, PyObject* storage_V85, PyObject* storage_V87, PyObject* storage_V89, PyObject* storage_V91, PyObject* storage_V93, PyObject* storage_V95, PyObject* storage_V97, PyObject* storage_V99, PyObject* storage_V101, PyObject* storage_V103, PyObject* storage_V105, PyObject* storage_V107, PyObject* storage_V109, PyObject* storage_V111, PyObject* storage_V113, PyObject* storage_V115, PyObject* storage_V117, PyObject* storage_V119, PyObject* storage_V121, PyObject* storage_V123, PyObject* storage_V125, PyObject* storage_V127, PyObject* storage_V129, PyObject* storage_V131, PyObject* storage_V133, PyObject* storage_V135, PyObject* storage_V137, PyObject* storage_V139, PyObject* storage_V141, PyObject* storage_V143, PyObject* storage_V145, PyObject* storage_V147, PyObject* storage_V149, PyObject* storage_V151, PyObject* storage_V153, PyObject* storage_V155, PyObject* storage_V157, PyObject* storage_V159, PyObject* storage_V161, PyObject* storage_V163, PyObject* storage_V165, PyObject* storage_V167, PyObject* storage_V169, PyObject* storage_V171, PyObject* storage_V173, PyObject* storage_V175, PyObject* storage_V177, PyObject* storage_V179, PyObject* storage_V181, PyObject* storage_V183, PyObject* storage_V185, PyObject* storage_V187, PyObject* storage_V189, PyObject* storage_V191, PyObject* storage_V193, PyObject* storage_V195, PyObject* storage_V197, PyObject* storage_V199, PyObject* storage_V201, PyObject* storage_V203, PyObject* storage_V205, PyObject* storage_V207, PyObject* storage_V209, PyObject* storage_V211, PyObject* storage_V213, PyObject* storage_V215, PyObject* storage_V217, PyObject* storage_V219, PyObject* storage_V221, PyObject* storage_V223, PyObject* storage_V225, PyObject* storage_V227, PyObject* storage_V229, PyObject* storage_V231, PyObject* storage_V233, PyObject* storage_V235, PyObject* storage_V237, PyObject* storage_V239, PyObject* storage_V241, PyObject* storage_V243, PyObject* storage_V245, PyObject* storage_V247, PyObject* storage_V249, PyObject* storage_V251, PyObject* storage_V253, PyObject* storage_V255, PyObject* storage_V257, PyObject* storage_V259, PyObject* storage_V261, PyObject* storage_V263, PyObject* storage_V265, PyObject* storage_V267, PyObject* storage_V269, PyObject* storage_V271, PyObject* storage_V273, PyObject* storage_V275, PyObject* storage_V277, PyObject* storage_V279, PyObject* storage_V281, PyObject* storage_V283, PyObject* storage_V285, PyObject* storage_V287, PyObject* storage_V289, PyObject* storage_V291, PyObject* storage_V293, PyObject* storage_V295, PyObject* storage_V297, PyObject* storage_V299, PyObject* storage_V301, PyObject* storage_V303, PyObject* storage_V305, PyObject* storage_V307, PyObject* storage_V309, PyObject* storage_V311, PyObject* storage_V313, PyObject* storage_V315, PyObject* storage_V317, PyObject* storage_V319, PyObject* storage_V321, PyObject* storage_V323, PyObject* storage_V325, PyObject* storage_V327, PyObject* storage_V329, PyObject* storage_V331, PyObject* storage_V333, PyObject* storage_V335, PyO ...
# 00390	            Py_XINCREF(storage_V3);
# 00391	Py_XINCREF(storage_V5);
# 00392	Py_XINCREF(storage_V7);
# 00393	Py_XINCREF(storage_V9);
# 00394	Py_XINCREF(storage_V11);
# 00395	Py_XINCREF(storage_V13);
# 00396	Py_XINCREF(storage_V15);
# 00397	Py_XINCREF(storage_V17);
# 00398	Py_XINCREF(storage_V19);
# 00399	Py_XINCREF(storage_V21);
# 00400	Py_XINCREF(storage_V23);
# 00401	Py_XINCREF(storage_V25);
# 00402	Py_XINCREF(storage_V27);
# 00403	Py_XINCREF(storage_V29);
# 00404	Py_XINCREF(storage_V31);
# 00405	Py_XINCREF(storage_V33);
# 00406	Py_XINCREF(storage_V35);
# 00407	Py_XINCREF(storage_V37);
# 00408	Py_XINCREF(storage_V39);
# 00409	Py_XINCREF(storage_V41);
# 00410	Py_XINCREF(storage_V43);
# 00411	Py_XINCREF(storage_V45);
# 00412	Py_XINCREF(storage_V47);
# 00413	Py_XINCREF(storage_V49);
# 00414	Py_XINCREF(storage_V51);
# 00415	Py_XINCREF(storage_V53);
# 00416	Py_XINCREF(storage_V55);
# 00417	Py_XINCREF(storage_V57);
# 00418	Py_XINCREF(storage_V59);
# 00419	Py_XINCREF(storage_V61);
# 00420	Py_XINCREF(storage_V63);
# 00421	Py_XINCREF(storage_V65);
# 00422	Py_XINCREF(storage_V67);
# 00423	Py_XINCREF(storage_V69);
# 00424	Py_XINCREF(storage_V71);
# 00425	Py_XINCREF(storage_V73);
# 00426	Py_XINCREF(storage_V75);
# 00427	Py_XINCREF(storage_V77);
# 00428	Py_XINCREF(storage_V79);
# 00429	Py_XINCREF(storage_V81);
# 00430	Py_XINCREF(storage_V83);
# 00431	Py_XINCREF(storage_V85);
# 00432	Py_XINCREF(storage_V87);
# 00433	Py_XINCREF(storage_V89);
# 00434	Py_XINCREF(storage_V91);
# 00435	Py_XINCREF(storage_V93);
# 00436	Py_XINCREF(storage_V95);
# 00437	Py_XINCREF(storage_V97);
# 00438	Py_XINCREF(storage_V99);
# 00439	Py_XINCREF(storage_V101);
# 00440	Py_XINCREF(storage_V103);
# 00441	Py_XINCREF(storage_V105);
# 00442	Py_XINCREF(storage_V107);
# 00443	Py_XINCREF(storage_V109);
# 00444	Py_XINCREF(storage_V111);
# 00445	Py_XINCREF(storage_V113);
# 00446	Py_XINCREF(storage_V115);
# 00447	Py_XINCREF(storage_V117);
# 00448	Py_XINCREF(storage_V119);
# 00449	Py_XINCREF(storage_V121);
# 00450	Py_XINCREF(storage_V123);
# 00451	Py_XINCREF(storage_V125);
# 00452	Py_XINCREF(storage_V127);
# 00453	Py_XINCREF(storage_V129);
# 00454	Py_XINCREF(storage_V131);
# 00455	Py_XINCREF(storage_V133);
# 00456	Py_XINCREF(storage_V135);
# 00457	Py_XINCREF(storage_V137);
# 00458	Py_XINCREF(storage_V139);
# 00459	Py_XINCREF(storage_V141);
# 00460	Py_XINCREF(storage_V143);
# 00461	Py_XINCREF(storage_V145);
# 00462	Py_XINCREF(storage_V147);
# 00463	Py_XINCREF(storage_V149);
# 00464	Py_XINCREF(storage_V151);
# 00465	Py_XINCREF(storage_V153);
# 00466	Py_XINCREF(storage_V155);
# 00467	Py_XINCREF(storage_V157);
# 00468	Py_XINCREF(storage_V159);
# 00469	Py_XINCREF(storage_V161);
# 00470	Py_XINCREF(storage_V163);
# 00471	Py_XINCREF(storage_V165);
# 00472	Py_XINCREF(storage_V167);
# 00473	Py_XINCREF(storage_V169);
# 00474	Py_XINCREF(storage_V171);
# 00475	Py_XINCREF(storage_V173);
# 00476	Py_XINCREF(storage_V175);
# 00477	Py_XINCREF(storage_V177);
# 00478	Py_XINCREF(storage_V179);
# 00479	Py_XINCREF(storage_V181);
# 00480	Py_XINCREF(storage_V183);
# 00481	Py_XINCREF(storage_V185);
# 00482	Py_XINCREF(storage_V187);
# 00483	Py_XINCREF(storage_V189);
# 00484	Py_XINCREF(storage_V191);
# 00485	Py_XINCREF(storage_V193);
# 00486	Py_XINCREF(storage_V195);
# 00487	Py_XINCREF(storage_V197);
# 00488	Py_XINCREF(storage_V199);
# 00489	Py_XINCREF(storage_V201);
# 00490	Py_XINCREF(storage_V203);
# 00491	Py_XINCREF(storage_V205);
# 00492	Py_XINCREF(storage_V207);
# 00493	Py_XINCREF(storage_V209);
# 00494	Py_XINCREF(storage_V211);
# 00495	Py_XINCREF(storage_V213);
# 00496	Py_XINCREF(storage_V215);
# 00497	Py_XINCREF(storage_V217);
# 00498	Py_XINCREF(storage_V219);
# 00499	Py_XINCREF(storage_V221);
# 00500	Py_XINCREF(storage_V223);
# 00501	Py_XINCREF(storage_V225);
# 00502	Py_XINCREF(storage_V227);
# 00503	Py_XINCREF(storage_V229);
# 00504	Py_XINCREF(storage_V231);
# 00505	Py_XINCREF(storage_V233);
# 00506	Py_XINCREF(storage_V235);
# 00507	Py_XINCREF(storage_V237);
# 00508	Py_XINCREF(storage_V239);
# 00509	Py_XINCREF(storage_V241);
# 00510	Py_XINCREF(storage_V243);
# 00511	Py_XINCREF(storage_V245);
# 00512	Py_XINCREF(storage_V247);
# 00513	Py_XINCREF(storage_V249);
# 00514	Py_XINCREF(storage_V251);
# 00515	Py_XINCREF(storage_V253);
# 00516	Py_XINCREF(storage_V255);
# 00517	Py_XINCREF(storage_V257);
# 00518	Py_XINCREF(storage_V259);
# 00519	Py_XINCREF(storage_V261);
# 00520	Py_XINCREF(storage_V263);
# 00521	Py_XINCREF(storage_V265);
# 00522	Py_XINCREF(storage_V267);
# 00523	Py_XINCREF(storage_V269);
# 00524	Py_XINCREF(storage_V271);
# 00525	Py_XINCREF(storage_V273);
# 00526	Py_XINCREF(storage_V275);
# 00527	Py_XINCREF(storage_V277);
# 00528	Py_XINCREF(storage_V279);
# 00529	Py_XINCREF(storage_V281);
# 00530	Py_XINCREF(storage_V283);
# 00531	Py_XINCREF(storage_V285);
# 00532	Py_XINCREF(storage_V287);
# 00533	Py_XINCREF(storage_V289);
# 00534	Py_XINCREF(storage_V291);
# 00535	Py_XINCREF(storage_V293);
# 00536	Py_XINCREF(storage_V295);
# 00537	Py_XINCREF(storage_V297);
# 00538	Py_XINCREF(storage_V299);
# 00539	Py_XINCREF(storage_V301);
# 00540	Py_XINCREF(storage_V303);
# 00541	Py_XINCREF(storage_V305);
# 00542	Py_XINCREF(storage_V307);
# 00543	Py_XINCREF(storage_V309);
# 00544	Py_XINCREF(storage_V311);
# 00545	Py_XINCREF(storage_V313);
# 00546	Py_XINCREF(storage_V315);
# 00547	Py_XINCREF(storage_V317);
# 00548	Py_XINCREF(storage_V319);
# 00549	Py_XINCREF(storage_V321);
# 00550	Py_XINCREF(storage_V323);
# 00551	Py_XINCREF(storage_V325);
# 00552	Py_XINCREF(storage_V327);
# 00553	Py_XINCREF(storage_V329);
# 00554	Py_XINCREF(storage_V331);
# 00555	Py_XINCREF(storage_V333);
# 00556	Py_XINCREF(storage_V335);
# 00557	Py_XINCREF(storage_V337);
# 00558	Py_XINCREF(storage_V339);
# 00559	Py_XINCREF(storage_V341);
# 00560	Py_XINCREF(storage_V343);
# 00561	Py_XINCREF(storage_V345);
# 00562	Py_XINCREF(storage_V347);
# 00563	Py_XINCREF(storage_V349);
# 00564	Py_XINCREF(storage_V351);
# 00565	Py_XINCREF(storage_V353);
# 00566	Py_XINCREF(storage_V355);
# 00567	Py_XINCREF(storage_V357);
# 00568	Py_XINCREF(storage_V359);
# 00569	Py_XINCREF(storage_V361);
# 00570	Py_XINCREF(storage_V363);
# 00571	Py_XINCREF(storage_V365);
# 00572	Py_XINCREF(storage_V367);
# 00573	Py_XINCREF(storage_V369);
# 00574	Py_XINCREF(storage_V371);
# 00575	Py_XINCREF(storage_V373);
# 00576	Py_XINCREF(storage_V375);
# 00577	Py_XINCREF(storage_V377);
# 00578	Py_XINCREF(storage_V379);
# 00579	Py_XINCREF(storage_V381);
# 00580	Py_XINCREF(storage_V383);
# 00581	Py_XINCREF(storage_V385);
# 00582	Py_XINCREF(storage_V387);
# 00583	Py_XINCREF(storage_V389);
# 00584	Py_XINCREF(storage_V391);
# 00585	Py_XINCREF(storage_V393);
# 00586	Py_XINCREF(storage_V395);
# 00587	Py_XINCREF(storage_V397);
# 00588	Py_XINCREF(storage_V399);
# 00589	Py_XINCREF(storage_V401);
# 00590	Py_XINCREF(storage_V403);
# 00591	Py_XINCREF(storage_V405);
# 00592	Py_XINCREF(storage_V407);
# 00593	Py_XINCREF(storage_V409);
# 00594	Py_XINCREF(storage_V411);
# 00595	Py_XINCREF(storage_V413);
# 00596	Py_XINCREF(storage_V415);
# 00597	Py_XINCREF(storage_V417);
# 00598	Py_XINCREF(storage_V419);
# 00599	Py_XINCREF(storage_V421);
# 00600	Py_XINCREF(storage_V423);
# 00601	Py_XINCREF(storage_V425);
# 00602	Py_XINCREF(storage_V427);
# 00603	Py_XINCREF(storage_V429);
# 00604	Py_XINCREF(storage_V431);
# 00605	Py_XINCREF(storage_V433);
# 00606	Py_XINCREF(storage_V435);
# 00607	Py_XINCREF(storage_V437);
# 00608	Py_XINCREF(storage_V439);
# 00609	Py_XINCREF(storage_V441);
# 00610	Py_XINCREF(storage_V443);
# 00611	Py_XINCREF(storage_V445);
# 00612	Py_XINCREF(storage_V447);
# 00613	Py_XINCREF(storage_V449);
# 00614	Py_XINCREF(storage_V451);
# 00615	Py_XINCREF(storage_V453);
# 00616	Py_XINCREF(storage_V455);
# 00617	Py_XINCREF(storage_V457);
# 00618	Py_XINCREF(storage_V459);
# 00619	Py_XINCREF(storage_V461);
# 00620	Py_XINCREF(storage_V463);
# 00621	Py_XINCREF(storage_V465);
# 00622	Py_XINCREF(storage_V467);
# 00623	Py_XINCREF(storage_V469);
# 00624	Py_XINCREF(storage_V471);
# 00625	Py_XINCREF(storage_V473);
# 00626	Py_XINCREF(storage_V475);
# 00627	Py_XINCREF(storage_V477);
# 00628	Py_XINCREF(storage_V479);
# 00629	Py_XINCREF(storage_V481);
# 00630	Py_XINCREF(storage_V483);
# 00631	Py_XINCREF(storage_V485);
# 00632	Py_XINCREF(storage_V487);
# 00633	Py_XINCREF(storage_V489);
# 00634	Py_XINCREF(storage_V491);
# 00635	Py_XINCREF(storage_V493);
# 00636	Py_XINCREF(storage_V495);
# 00637	Py_XINCREF(storage_V497);
# 00638	Py_XINCREF(storage_V499);
# 00639	Py_XINCREF(storage_V501);
# 00640	Py_XINCREF(storage_V503);
# 00641	Py_XINCREF(storage_V505);
# 00642	Py_XINCREF(storage_V507);
# 00643	Py_XINCREF(storage_V509);
# 00644	Py_XINCREF(storage_V511);
# 00645	Py_XINCREF(storage_V513);
# 00646	Py_XINCREF(storage_V515);
# 00647	Py_XINCREF(storage_V517);
# 00648	Py_XINCREF(storage_V519);
# 00649	Py_XINCREF(storage_V521);
# 00650	Py_XINCREF(storage_V523);
# 00651	Py_XINCREF(storage_V525);
# 00652	Py_XINCREF(storage_V527);
# 00653	Py_XINCREF(storage_V529);
# 00654	Py_XINCREF(storage_V531);
# 00655	Py_XINCREF(storage_V533);
# 00656	Py_XINCREF(storage_V535);
# 00657	Py_XINCREF(storage_V537);
# 00658	Py_XINCREF(storage_V539);
# 00659	Py_XINCREF(storage_V541);
# 00660	Py_XINCREF(storage_V543);
# 00661	Py_XINCREF(storage_V545);
# 00662	Py_XINCREF(storage_V547);
# 00663	Py_XINCREF(storage_V549);
# 00664	Py_XINCREF(storage_V551);
# 00665	Py_XINCREF(storage_V553);
# 00666	Py_XINCREF(storage_V555);
# 00667	Py_XINCREF(storage_V557);
# 00668	Py_XINCREF(storage_V559);
# 00669	Py_XINCREF(storage_V561);
# 00670	Py_XINCREF(storage_V563);
# 00671	Py_XINCREF(storage_V565);
# 00672	Py_XINCREF(storage_V567);
# 00673	Py_XINCREF(storage_V569);
# 00674	Py_XINCREF(storage_V571);
# 00675	Py_XINCREF(storage_V573);
# 00676	Py_XINCREF(storage_V575);
# 00677	Py_XINCREF(storage_V577);
# 00678	Py_XINCREF(storage_V579);
# 00679	Py_XINCREF(storage_V581);
# 00680	Py_XINCREF(storage_V583);
# 00681	Py_XINCREF(storage_V585);
# 00682	Py_XINCREF(storage_V587);
# 00683	Py_XINCREF(storage_V589);
# 00684	Py_XINCREF(storage_V591);
# 00685	Py_XINCREF(storage_V593);
# 00686	Py_XINCREF(storage_V595);
# 00687	Py_XINCREF(storage_V597);
# 00688	Py_XINCREF(storage_V599);
# 00689	Py_XINCREF(storage_V601);
# 00690	Py_XINCREF(storage_V603);
# 00691	Py_XINCREF(storage_V605);
# 00692	Py_XINCREF(storage_V607);
# 00693	Py_XINCREF(storage_V609);
# 00694	Py_XINCREF(storage_V611);
# 00695	Py_XINCREF(storage_V613);
# 00696	Py_XINCREF(storage_V615);
# 00697	Py_XINCREF(storage_V617);
# 00698	Py_XINCREF(storage_V619);
# 00699	Py_XINCREF(storage_V621);
# 00700	Py_XINCREF(storage_V623);
# 00701	Py_XINCREF(storage_V625);
# 00702	Py_XINCREF(storage_V627);
# 00703	Py_XINCREF(storage_V629);
# 00704	Py_XINCREF(storage_V631);
# 00705	Py_XINCREF(storage_V633);
# 00706	Py_XINCREF(storage_V635);
# 00707	Py_XINCREF(storage_V637);
# 00708	Py_XINCREF(storage_V639);
# 00709	Py_XINCREF(storage_V641);
# 00710	Py_XINCREF(storage_V643);
# 00711	Py_XINCREF(storage_V645);
# 00712	Py_XINCREF(storage_V647);
# 00713	Py_XINCREF(storage_V649);
# 00714	Py_XINCREF(storage_V651);
# 00715	Py_XINCREF(storage_V653);
# 00716	Py_XINCREF(storage_V655);
# 00717	Py_XINCREF(storage_V657);
# 00718	Py_XINCREF(storage_V659);
# 00719	Py_XINCREF(storage_V661);
# 00720	Py_XINCREF(storage_V663);
# 00721	Py_XINCREF(storage_V665);
# 00722	Py_XINCREF(storage_V667);
# 00723	Py_XINCREF(storage_V669);
# 00724	Py_XINCREF(storage_V671);
# 00725	Py_XINCREF(storage_V673);
# 00726	Py_XINCREF(storage_V675);
# 00727	Py_XINCREF(storage_V677);
# 00728	Py_XINCREF(storage_V679);
# 00729	Py_XINCREF(storage_V681);
# 00730	Py_XINCREF(storage_V683);
# 00731	Py_XINCREF(storage_V685);
# 00732	Py_XINCREF(storage_V687);
# 00733	Py_XINCREF(storage_V689);
# 00734	Py_XINCREF(storage_V691);
# 00735	Py_XINCREF(storage_V693);
# 00736	Py_XINCREF(storage_V695);
# 00737	Py_XINCREF(storage_V697);
# 00738	Py_XINCREF(storage_V699);
# 00739	Py_XINCREF(storage_V701);
# 00740	Py_XINCREF(storage_V703);
# 00741	Py_XINCREF(storage_V705);
# 00742	Py_XINCREF(storage_V707);
# 00743	Py_XINCREF(storage_V1);
# 00744	            this->storage_V3 = storage_V3;
# 00745	this->storage_V5 = storage_V5;
# 00746	this->storage_V7 = storage_V7;
# 00747	this->storage_V9 = storage_V9;
# 00748	this->storage_V11 = storage_V11;
# 00749	this->storage_V13 = storage_V13;
# 00750	this->storage_V15 = storage_V15;
# 00751	this->storage_V17 = storage_V17;
# 00752	this->storage_V19 = storage_V19;
# 00753	this->storage_V21 = storage_V21;
# 00754	this->storage_V23 = storage_V23;
# 00755	this->storage_V25 = storage_V25;
# 00756	this->storage_V27 = storage_V27;
# 00757	this->storage_V29 = storage_V29;
# 00758	this->storage_V31 = storage_V31;
# 00759	this->storage_V33 = storage_V33;
# 00760	this->storage_V35 = storage_V35;
# 00761	this->storage_V37 = storage_V37;
# 00762	this->storage_V39 = storage_V39;
# 00763	this->storage_V41 = storage_V41;
# 00764	this->storage_V43 = storage_V43;
# 00765	this->storage_V45 = storage_V45;
# 00766	this->storage_V47 = storage_V47;
# 00767	this->storage_V49 = storage_V49;
# 00768	this->storage_V51 = storage_V51;
# 00769	this->storage_V53 = storage_V53;
# 00770	this->storage_V55 = storage_V55;
# 00771	this->storage_V57 = storage_V57;
# 00772	this->storage_V59 = storage_V59;
# 00773	this->storage_V61 = storage_V61;
# 00774	this->storage_V63 = storage_V63;
# 00775	this->storage_V65 = storage_V65;
# 00776	this->storage_V67 = storage_V67;
# 00777	this->storage_V69 = storage_V69;
# 00778	this->storage_V71 = storage_V71;
# 00779	this->storage_V73 = storage_V73;
# 00780	this->storage_V75 = storage_V75;
# 00781	this->storage_V77 = storage_V77;
# 00782	this->storage_V79 = storage_V79;
# 00783	this->storage_V81 = storage_V81;
# 00784	this->storage_V83 = storage_V83;
# 00785	this->storage_V85 = storage_V85;
# 00786	this->storage_V87 = storage_V87;
# 00787	this->storage_V89 = storage_V89;
# 00788	this->storage_V91 = storage_V91;
# 00789	this->storage_V93 = storage_V93;
# 00790	this->storage_V95 = storage_V95;
# 00791	this->storage_V97 = storage_V97;
# 00792	this->storage_V99 = storage_V99;
# 00793	this->storage_V101 = storage_V101;
# 00794	this->storage_V103 = storage_V103;
# 00795	this->storage_V105 = storage_V105;
# 00796	this->storage_V107 = storage_V107;
# 00797	this->storage_V109 = storage_V109;
# 00798	this->storage_V111 = storage_V111;
# 00799	this->storage_V113 = storage_V113;
# 00800	this->storage_V115 = storage_V115;
# 00801	this->storage_V117 = storage_V117;
# 00802	this->storage_V119 = storage_V119;
# 00803	this->storage_V121 = storage_V121;
# 00804	this->storage_V123 = storage_V123;
# 00805	this->storage_V125 = storage_V125;
# 00806	this->storage_V127 = storage_V127;
# 00807	this->storage_V129 = storage_V129;
# 00808	this->storage_V131 = storage_V131;
# 00809	this->storage_V133 = storage_V133;
# 00810	this->storage_V135 = storage_V135;
# 00811	this->storage_V137 = storage_V137;
# 00812	this->storage_V139 = storage_V139;
# 00813	this->storage_V141 = storage_V141;
# 00814	this->storage_V143 = storage_V143;
# 00815	this->storage_V145 = storage_V145;
# 00816	this->storage_V147 = storage_V147;
# 00817	this->storage_V149 = storage_V149;
# 00818	this->storage_V151 = storage_V151;
# 00819	this->storage_V153 = storage_V153;
# 00820	this->storage_V155 = storage_V155;
# 00821	this->storage_V157 = storage_V157;
# 00822	this->storage_V159 = storage_V159;
# 00823	this->storage_V161 = storage_V161;
# 00824	this->storage_V163 = storage_V163;
# 00825	this->storage_V165 = storage_V165;
# 00826	this->storage_V167 = storage_V167;
# 00827	this->storage_V169 = storage_V169;
# 00828	this->storage_V171 = storage_V171;
# 00829	this->storage_V173 = storage_V173;
# 00830	this->storage_V175 = storage_V175;
# 00831	this->storage_V177 = storage_V177;
# 00832	this->storage_V179 = storage_V179;
# 00833	this->storage_V181 = storage_V181;
# 00834	this->storage_V183 = storage_V183;
# 00835	this->storage_V185 = storage_V185;
# 00836	this->storage_V187 = storage_V187;
# 00837	this->storage_V189 = storage_V189;
# 00838	this->storage_V191 = storage_V191;
# 00839	this->storage_V193 = storage_V193;
# 00840	this->storage_V195 = storage_V195;
# 00841	this->storage_V197 = storage_V197;
# 00842	this->storage_V199 = storage_V199;
# 00843	this->storage_V201 = storage_V201;
# 00844	this->storage_V203 = storage_V203;
# 00845	this->storage_V205 = storage_V205;
# 00846	this->storage_V207 = storage_V207;
# 00847	this->storage_V209 = storage_V209;
# 00848	this->storage_V211 = storage_V211;
# 00849	this->storage_V213 = storage_V213;
# 00850	this->storage_V215 = storage_V215;
# 00851	this->storage_V217 = storage_V217;
# 00852	this->storage_V219 = storage_V219;
# 00853	this->storage_V221 = storage_V221;
# 00854	this->storage_V223 = storage_V223;
# 00855	this->storage_V225 = storage_V225;
# 00856	this->storage_V227 = storage_V227;
# 00857	this->storage_V229 = storage_V229;
# 00858	this->storage_V231 = storage_V231;
# 00859	this->storage_V233 = storage_V233;
# 00860	this->storage_V235 = storage_V235;
# 00861	this->storage_V237 = storage_V237;
# 00862	this->storage_V239 = storage_V239;
# 00863	this->storage_V241 = storage_V241;
# 00864	this->storage_V243 = storage_V243;
# 00865	this->storage_V245 = storage_V245;
# 00866	this->storage_V247 = storage_V247;
# 00867	this->storage_V249 = storage_V249;
# 00868	this->storage_V251 = storage_V251;
# 00869	this->storage_V253 = storage_V253;
# 00870	this->storage_V255 = storage_V255;
# 00871	this->storage_V257 = storage_V257;
# 00872	this->storage_V259 = storage_V259;
# 00873	this->storage_V261 = storage_V261;
# 00874	this->storage_V263 = storage_V263;
# 00875	this->storage_V265 = storage_V265;
# 00876	this->storage_V267 = storage_V267;
# 00877	this->storage_V269 = storage_V269;
# 00878	this->storage_V271 = storage_V271;
# 00879	this->storage_V273 = storage_V273;
# 00880	this->storage_V275 = storage_V275;
# 00881	this->storage_V277 = storage_V277;
# 00882	this->storage_V279 = storage_V279;
# 00883	this->storage_V281 = storage_V281;
# 00884	this->storage_V283 = storage_V283;
# 00885	this->storage_V285 = storage_V285;
# 00886	this->storage_V287 = storage_V287;
# 00887	this->storage_V289 = storage_V289;
# 00888	this->storage_V291 = storage_V291;
# 00889	this->storage_V293 = storage_V293;
# 00890	this->storage_V295 = storage_V295;
# 00891	this->storage_V297 = storage_V297;
# 00892	this->storage_V299 = storage_V299;
# 00893	this->storage_V301 = storage_V301;
# 00894	this->storage_V303 = storage_V303;
# 00895	this->storage_V305 = storage_V305;
# 00896	this->storage_V307 = storage_V307;
# 00897	this->storage_V309 = storage_V309;
# 00898	this->storage_V311 = storage_V311;
# 00899	this->storage_V313 = storage_V313;
# 00900	this->storage_V315 = storage_V315;
# 00901	this->storage_V317 = storage_V317;
# 00902	this->storage_V319 = storage_V319;
# 00903	this->storage_V321 = storage_V321;
# 00904	this->storage_V323 = storage_V323;
# 00905	this->storage_V325 = storage_V325;
# 00906	this->storage_V327 = storage_V327;
# 00907	this->storage_V329 = storage_V329;
# 00908	this->storage_V331 = storage_V331;
# 00909	this->storage_V333 = storage_V333;
# 00910	this->storage_V335 = storage_V335;
# 00911	this->storage_V337 = storage_V337;
# 00912	this->storage_V339 = storage_V339;
# 00913	this->storage_V341 = storage_V341;
# 00914	this->storage_V343 = storage_V343;
# 00915	this->storage_V345 = storage_V345;
# 00916	this->storage_V347 = storage_V347;
# 00917	this->storage_V349 = storage_V349;
# 00918	this->storage_V351 = storage_V351;
# 00919	this->storage_V353 = storage_V353;
# 00920	this->storage_V355 = storage_V355;
# 00921	this->storage_V357 = storage_V357;
# 00922	this->storage_V359 = storage_V359;
# 00923	this->storage_V361 = storage_V361;
# 00924	this->storage_V363 = storage_V363;
# 00925	this->storage_V365 = storage_V365;
# 00926	this->storage_V367 = storage_V367;
# 00927	this->storage_V369 = storage_V369;
# 00928	this->storage_V371 = storage_V371;
# 00929	this->storage_V373 = storage_V373;
# 00930	this->storage_V375 = storage_V375;
# 00931	this->storage_V377 = storage_V377;
# 00932	this->storage_V379 = storage_V379;
# 00933	this->storage_V381 = storage_V381;
# 00934	this->storage_V383 = storage_V383;
# 00935	this->storage_V385 = storage_V385;
# 00936	this->storage_V387 = storage_V387;
# 00937	this->storage_V389 = storage_V389;
# 00938	this->storage_V391 = storage_V391;
# 00939	this->storage_V393 = storage_V393;
# 00940	this->storage_V395 = storage_V395;
# 00941	this->storage_V397 = storage_V397;
# 00942	this->storage_V399 = storage_V399;
# 00943	this->storage_V401 = storage_V401;
# 00944	this->storage_V403 = storage_V403;
# 00945	this->storage_V405 = storage_V405;
# 00946	this->storage_V407 = storage_V407;
# 00947	this->storage_V409 = storage_V409;
# 00948	this->storage_V411 = storage_V411;
# 00949	this->storage_V413 = storage_V413;
# 00950	this->storage_V415 = storage_V415;
# 00951	this->storage_V417 = storage_V417;
# 00952	this->storage_V419 = storage_V419;
# 00953	this->storage_V421 = storage_V421;
# 00954	this->storage_V423 = storage_V423;
# 00955	this->storage_V425 = storage_V425;
# 00956	this->storage_V427 = storage_V427;
# 00957	this->storage_V429 = storage_V429;
# 00958	this->storage_V431 = storage_V431;
# 00959	this->storage_V433 = storage_V433;
# 00960	this->storage_V435 = storage_V435;
# 00961	this->storage_V437 = storage_V437;
# 00962	this->storage_V439 = storage_V439;
# 00963	this->storage_V441 = storage_V441;
# 00964	this->storage_V443 = storage_V443;
# 00965	this->storage_V445 = storage_V445;
# 00966	this->storage_V447 = storage_V447;
# 00967	this->storage_V449 = storage_V449;
# 00968	this->storage_V451 = storage_V451;
# 00969	this->storage_V453 = storage_V453;
# 00970	this->storage_V455 = storage_V455;
# 00971	this->storage_V457 = storage_V457;
# 00972	this->storage_V459 = storage_V459;
# 00973	this->storage_V461 = storage_V461;
# 00974	this->storage_V463 = storage_V463;
# 00975	this->storage_V465 = storage_V465;
# 00976	this->storage_V467 = storage_V467;
# 00977	this->storage_V469 = storage_V469;
# 00978	this->storage_V471 = storage_V471;
# 00979	this->storage_V473 = storage_V473;
# 00980	this->storage_V475 = storage_V475;
# 00981	this->storage_V477 = storage_V477;
# 00982	this->storage_V479 = storage_V479;
# 00983	this->storage_V481 = storage_V481;
# 00984	this->storage_V483 = storage_V483;
# 00985	this->storage_V485 = storage_V485;
# 00986	this->storage_V487 = storage_V487;
# 00987	this->storage_V489 = storage_V489;
# 00988	this->storage_V491 = storage_V491;
# 00989	this->storage_V493 = storage_V493;
# 00990	this->storage_V495 = storage_V495;
# 00991	this->storage_V497 = storage_V497;
# 00992	this->storage_V499 = storage_V499;
# 00993	this->storage_V501 = storage_V501;
# 00994	this->storage_V503 = storage_V503;
# 00995	this->storage_V505 = storage_V505;
# 00996	this->storage_V507 = storage_V507;
# 00997	this->storage_V509 = storage_V509;
# 00998	this->storage_V511 = storage_V511;
# 00999	this->storage_V513 = storage_V513;
# 01000	this->storage_V515 = storage_V515;
# 01001	this->storage_V517 = storage_V517;
# 01002	this->storage_V519 = storage_V519;
# 01003	this->storage_V521 = storage_V521;
# 01004	this->storage_V523 = storage_V523;
# 01005	this->storage_V525 = storage_V525;
# 01006	this->storage_V527 = storage_V527;
# 01007	this->storage_V529 = storage_V529;
# 01008	this->storage_V531 = storage_V531;
# 01009	this->storage_V533 = storage_V533;
# 01010	this->storage_V535 = storage_V535;
# 01011	this->storage_V537 = storage_V537;
# 01012	this->storage_V539 = storage_V539;
# 01013	this->storage_V541 = storage_V541;
# 01014	this->storage_V543 = storage_V543;
# 01015	this->storage_V545 = storage_V545;
# 01016	this->storage_V547 = storage_V547;
# 01017	this->storage_V549 = storage_V549;
# 01018	this->storage_V551 = storage_V551;
# 01019	this->storage_V553 = storage_V553;
# 01020	this->storage_V555 = storage_V555;
# 01021	this->storage_V557 = storage_V557;
# 01022	this->storage_V559 = storage_V559;
# 01023	this->storage_V561 = storage_V561;
# 01024	this->storage_V563 = storage_V563;
# 01025	this->storage_V565 = storage_V565;
# 01026	this->storage_V567 = storage_V567;
# 01027	this->storage_V569 = storage_V569;
# 01028	this->storage_V571 = storage_V571;
# 01029	this->storage_V573 = storage_V573;
# 01030	this->storage_V575 = storage_V575;
# 01031	this->storage_V577 = storage_V577;
# 01032	this->storage_V579 = storage_V579;
# 01033	this->storage_V581 = storage_V581;
# 01034	this->storage_V583 = storage_V583;
# 01035	this->storage_V585 = storage_V585;
# 01036	this->storage_V587 = storage_V587;
# 01037	this->storage_V589 = storage_V589;
# 01038	this->storage_V591 = storage_V591;
# 01039	this->storage_V593 = storage_V593;
# 01040	this->storage_V595 = storage_V595;
# 01041	this->storage_V597 = storage_V597;
# 01042	this->storage_V599 = storage_V599;
# 01043	this->storage_V601 = storage_V601;
# 01044	this->storage_V603 = storage_V603;
# 01045	this->storage_V605 = storage_V605;
# 01046	this->storage_V607 = storage_V607;
# 01047	this->storage_V609 = storage_V609;
# 01048	this->storage_V611 = storage_V611;
# 01049	this->storage_V613 = storage_V613;
# 01050	this->storage_V615 = storage_V615;
# 01051	this->storage_V617 = storage_V617;
# 01052	this->storage_V619 = storage_V619;
# 01053	this->storage_V621 = storage_V621;
# 01054	this->storage_V623 = storage_V623;
# 01055	this->storage_V625 = storage_V625;
# 01056	this->storage_V627 = storage_V627;
# 01057	this->storage_V629 = storage_V629;
# 01058	this->storage_V631 = storage_V631;
# 01059	this->storage_V633 = storage_V633;
# 01060	this->storage_V635 = storage_V635;
# 01061	this->storage_V637 = storage_V637;
# 01062	this->storage_V639 = storage_V639;
# 01063	this->storage_V641 = storage_V641;
# 01064	this->storage_V643 = storage_V643;
# 01065	this->storage_V645 = storage_V645;
# 01066	this->storage_V647 = storage_V647;
# 01067	this->storage_V649 = storage_V649;
# 01068	this->storage_V651 = storage_V651;
# 01069	this->storage_V653 = storage_V653;
# 01070	this->storage_V655 = storage_V655;
# 01071	this->storage_V657 = storage_V657;
# 01072	this->storage_V659 = storage_V659;
# 01073	this->storage_V661 = storage_V661;
# 01074	this->storage_V663 = storage_V663;
# 01075	this->storage_V665 = storage_V665;
# 01076	this->storage_V667 = storage_V667;
# 01077	this->storage_V669 = storage_V669;
# 01078	this->storage_V671 = storage_V671;
# 01079	this->storage_V673 = storage_V673;
# 01080	this->storage_V675 = storage_V675;
# 01081	this->storage_V677 = storage_V677;
# 01082	this->storage_V679 = storage_V679;
# 01083	this->storage_V681 = storage_V681;
# 01084	this->storage_V683 = storage_V683;
# 01085	this->storage_V685 = storage_V685;
# 01086	this->storage_V687 = storage_V687;
# 01087	this->storage_V689 = storage_V689;
# 01088	this->storage_V691 = storage_V691;
# 01089	this->storage_V693 = storage_V693;
# 01090	this->storage_V695 = storage_V695;
# 01091	this->storage_V697 = storage_V697;
# 01092	this->storage_V699 = storage_V699;
# 01093	this->storage_V701 = storage_V701;
# 01094	this->storage_V703 = storage_V703;
# 01095	this->storage_V705 = storage_V705;
# 01096	this->storage_V707 = storage_V707;
# 01097	this->storage_V1 = storage_V1;
# 01098
# 01099
# 01100
# 01101
# 01102
# 01103
# 01104
# 01105
# 01106
# 01107
# 01108
# 01109
# 01110
# 01111
# 01112
# 01113
# 01114
# 01115
# 01116
# 01117
# 01118
# 01119
# 01120
# 01121
# 01122
# 01123
# 01124
# 01125
# 01126
# 01127
# 01128
# 01129
# 01130
# 01131
# 01132
# 01133
# 01134
# 01135
# 01136
# 01137
# 01138
# 01139
# 01140
# 01141
# 01142
# 01143
# 01144
# 01145
# 01146
# 01147
# 01148
# 01149
# 01150
# 01151
# 01152
# 01153
# 01154
# 01155
# 01156
# 01157
# 01158
# 01159
# 01160
# 01161
# 01162
# 01163
# 01164
# 01165
# 01166
# 01167
# 01168
# 01169
# 01170
# 01171
# 01172
# 01173
# 01174
# 01175
# 01176
# 01177
# 01178
# 01179
# 01180
# 01181
# 01182
# 01183
# 01184
# 01185
# 01186
# 01187
# 01188
# 01189
# 01190
# 01191
# 01192
# 01193
# 01194
# 01195
# 01196
# 01197
# 01198
# 01199
# 01200
# 01201
# 01202
# 01203
# 01204
# 01205
# 01206
# 01207
# 01208
# 01209
# 01210
# 01211
# 01212
# 01213
# 01214
# 01215
# 01216
# 01217
# 01218
# 01219
# 01220
# 01221
# 01222
# 01223
# 01224
# 01225
# 01226
# 01227
# 01228
# 01229
# 01230
# 01231
# 01232
# 01233
# 01234
# 01235
# 01236
# 01237
# 01238
# 01239
# 01240
# 01241
# 01242
# 01243
# 01244
# 01245
# 01246
# 01247
# 01248
# 01249
# 01250
# 01251
# 01252
# 01253
# 01254
# 01255
# 01256
# 01257
# 01258
# 01259
# 01260
# 01261
# 01262
# 01263
# 01264
# 01265
# 01266
# 01267
# 01268
# 01269
# 01270
# 01271
# 01272
# 01273
# 01274
# 01275
# 01276
# 01277
# 01278
# 01279
# 01280
# 01281
# 01282
# 01283
# 01284
# 01285
# 01286
# 01287
# 01288
# 01289
# 01290
# 01291
# 01292
# 01293
# 01294
# 01295
# 01296
# 01297
# 01298
# 01299
# 01300
# 01301
# 01302
# 01303
# 01304
# 01305
# 01306
# 01307
# 01308
# 01309
# 01310
# 01311
# 01312
# 01313
# 01314
# 01315
# 01316
# 01317
# 01318
# 01319
# 01320
# 01321
# 01322
# 01323
# 01324
# 01325
# 01326
# 01327
# 01328
# 01329
# 01330
# 01331
# 01332
# 01333
# 01334
# 01335
# 01336
# 01337
# 01338
# 01339
# 01340
# 01341
# 01342
# 01343
# 01344
# 01345
# 01346
# 01347
# 01348
# 01349
# 01350
# 01351
# 01352
# 01353
# 01354
# 01355
# 01356
# 01357
# 01358
# 01359
# 01360
# 01361
# 01362
# 01363
# 01364
# 01365
# 01366
# 01367
# 01368
# 01369
# 01370
# 01371
# 01372
# 01373
# 01374
# 01375
# 01376
# 01377
# 01378
# 01379
# 01380
# 01381
# 01382
# 01383
# 01384
# 01385
# 01386
# 01387
# 01388
# 01389
# 01390
# 01391
# 01392
# 01393
# 01394
# 01395
# 01396
# 01397
# 01398
# 01399
# 01400
# 01401
# 01402
# 01403
# 01404
# 01405
# 01406
# 01407
# 01408
# 01409
# 01410
# 01411
# 01412
# 01413
# 01414
# 01415
# 01416
# 01417
# 01418
# 01419
# 01420
# 01421
# 01422
# 01423
# 01424
# 01425
# 01426
# 01427
# 01428
# 01429
# 01430
# 01431
# 01432
# 01433
# 01434
# 01435
# 01436
# 01437
# 01438
# 01439
# 01440
# 01441
# 01442
# 01443
# 01444
# 01445
# 01446
# 01447
# 01448
# 01449
# 01450
# 01451
# 01452
# 01453
# 01454	            this->__ERROR = __ERROR;
# 01455	            return 0;
# 01456	        }
# 01457	        void cleanup(void) {
# 01458	            __label_1:
# 01459
# 01460	double __DUMMY_1;
# 01461	__label_3:
# 01462
# 01463	double __DUMMY_3;
# 01464	__label_5:
# 01465
# 01466	double __DUMMY_5;
# 01467	__label_7:
# 01468
# 01469	double __DUMMY_7;
# 01470	__label_9:
# 01471
# 01472	double __DUMMY_9;
# 01473	__label_11:
# 01474
# 01475	double __DUMMY_11;
# 01476	__label_13:
# 01477
# 01478	double __DUMMY_13;
# 01479	__label_15:
# 01480
# 01481	double __DUMMY_15;
# 01482	__label_17:
# 01483
# 01484	double __DUMMY_17;
# 01485	__label_19:
# 01486
# 01487	double __DUMMY_19;
# 01488	__label_21:
# 01489
# 01490	double __DUMMY_21;
# 01491	__label_23:
# 01492
# 01493	double __DUMMY_23;
# 01494	__label_25:
# 01495
# 01496	double __DUMMY_25;
# 01497	__label_27:
# 01498
# 01499	double __DUMMY_27;
# 01500	__label_29:
# 01501
# 01502	double __DUMMY_29;
# 01503	__label_31:
# 01504
# 01505	double __DUMMY_31;
# 01506	__label_33:
# 01507
# 01508	double __DUMMY_33;
# 01509	__label_35:
# 01510
# 01511	double __DUMMY_35;
# 01512	__label_37:
# 01513
# 01514	double __DUMMY_37;
# 01515	__label_39:
# 01516
# 01517	double __DUMMY_39;
# 01518	__label_41:
# 01519
# 01520	double __DUMMY_41;
# 01521	__label_43:
# 01522
# 01523	double __DUMMY_43;
# 01524	__label_45:
# 01525
# 01526	double __DUMMY_45;
# 01527	__label_47:
# 01528
# 01529	double __DUMMY_47;
# 01530	__label_49:
# 01531
# 01532	double __DUMMY_49;
# 01533	__label_51:
# 01534
# 01535	double __DUMMY_51;
# 01536	__label_53:
# 01537
# 01538	double __DUMMY_53;
# 01539	__label_55:
# 01540
# 01541	double __DUMMY_55;
# 01542	__label_57:
# 01543
# 01544	double __DUMMY_57;
# 01545	__label_59:
# 01546
# 01547	double __DUMMY_59;
# 01548	__label_61:
# 01549
# 01550	double __DUMMY_61;
# 01551	__label_63:
# 01552
# 01553	double __DUMMY_63;
# 01554	__label_65:
# 01555
# 01556	double __DUMMY_65;
# 01557	__label_67:
# 01558
# 01559	double __DUMMY_67;
# 01560	__label_69:
# 01561
# 01562	double __DUMMY_69;
# 01563	__label_71:
# 01564
# 01565	double __DUMMY_71;
# 01566	__label_73:
# 01567
# 01568	double __DUMMY_73;
# 01569	__label_75:
# 01570
# 01571	double __DUMMY_75;
# 01572	__label_77:
# 01573
# 01574	double __DUMMY_77;
# 01575	__label_79:
# 01576
# 01577	double __DUMMY_79;
# 01578	__label_81:
# 01579
# 01580	double __DUMMY_81;
# 01581	__label_83:
# 01582
# 01583	double __DUMMY_83;
# 01584	__label_85:
# 01585
# 01586	double __DUMMY_85;
# 01587	__label_87:
# 01588
# 01589	double __DUMMY_87;
# 01590	__label_89:
# 01591
# 01592	double __DUMMY_89;
# 01593	__label_91:
# 01594
# 01595	double __DUMMY_91;
# 01596	__label_93:
# 01597
# 01598	double __DUMMY_93;
# 01599	__label_95:
# 01600
# 01601	double __DUMMY_95;
# 01602	__label_97:
# 01603
# 01604	double __DUMMY_97;
# 01605	__label_99:
# 01606
# 01607	double __DUMMY_99;
# 01608	__label_101:
# 01609
# 01610	double __DUMMY_101;
# 01611	__label_103:
# 01612
# 01613	double __DUMMY_103;
# 01614	__label_105:
# 01615
# 01616	double __DUMMY_105;
# 01617	__label_107:
# 01618
# 01619	double __DUMMY_107;
# 01620	__label_109:
# 01621
# 01622	double __DUMMY_109;
# 01623	__label_111:
# 01624
# 01625	double __DUMMY_111;
# 01626	__label_113:
# 01627
# 01628	double __DUMMY_113;
# 01629	__label_115:
# 01630
# 01631	double __DUMMY_115;
# 01632	__label_117:
# 01633
# 01634	double __DUMMY_117;
# 01635	__label_119:
# 01636
# 01637	double __DUMMY_119;
# 01638	__label_121:
# 01639
# 01640	double __DUMMY_121;
# 01641	__label_123:
# 01642
# 01643	double __DUMMY_123;
# 01644	__label_125:
# 01645
# 01646	double __DUMMY_125;
# 01647	__label_127:
# 01648
# 01649	double __DUMMY_127;
# 01650	__label_129:
# 01651
# 01652	double __DUMMY_129;
# 01653	__label_131:
# 01654
# 01655	double __DUMMY_131;
# 01656	__label_133:
# 01657
# 01658	double __DUMMY_133;
# 01659	__label_135:
# 01660
# 01661	double __DUMMY_135;
# 01662	__label_137:
# 01663
# 01664	double __DUMMY_137;
# ...
# 41831	    delete struct_ptr;
# 41832	    return NULL;
# 41833	  }
# 41834	    PyObject* thunk = PyCapsule_New((void*)(&__struct_compiled_op_m8c3e8e4c4477ca5f184195f00826ad83_executor), NULL, __struct_compiled_op_m8c3e8e4c4477ca5f184195f00826ad83_destructor);
# 41835	    if (thunk != NULL && PyCapsule_SetContext(thunk, struct_ptr) != 0) {
# 41836	        PyErr_Clear();
# 41837	        Py_DECREF(thunk);
# 41838	        thunk = NULL;
# 41839	    }
# 41840
# 41841	  return thunk; }
# 41842
# 41843	//////////////////////
# 41844	////  Module init
# 41845	//////////////////////
# 41846	static PyMethodDef MyMethods[] = {
# 41847		{"instantiate", instantiate, METH_VARARGS, "undocumented"} ,
# 41848		{NULL, NULL, 0, NULL}
# 41849	};
# 41850	static struct PyModuleDef moduledef = {
# 41851	      PyModuleDef_HEAD_INIT,
# 41852	      "m8c3e8e4c4477ca5f184195f00826ad83",
# 41853	      NULL,
# 41854	      -1,
# 41855	      MyMethods,
# 41856	};
# 41857
# 41858	PyMODINIT_FUNC PyInit_m8c3e8e4c4477ca5f184195f00826ad83(void) {
# 41859	   import_array();
# 41860	    PyObject *m = PyModule_Create(&moduledef);
# 41861	    return m;
# 41862	}
# 41863
# Problem occurred during compilation with the command line below:
# /usr/bin/clang++ -dynamiclib -g -O3 -fno-math-errno -Wno-unused-label -Wno-unused-variable -Wno-write-strings -march=haswell -DNPY_NO_DEPRECATED_API=NPY_1_7_API_VERSION -m64 -fPIC -undefined dynamic_lookup -I/Users/claus/anaconda3/lib/python3.6/site-packages/numpy/core/include -I/Users/claus/anaconda3/include/python3.6m -I/Users/claus/anaconda3/lib/python3.6/site-packages/theano/gof -L/Users/claus/anaconda3/lib -fvisibility=hidden -o /Users/claus/.theano/compiledir_Darwin-16.7.0-x86_64-i386-64bit-i386-3.6.2-64/tmpwxirmnj7/m8c3e8e4c4477ca5f184195f00826ad83.so /Users/claus/.theano/compiledir_Darwin-16.7.0-x86_64-i386-64bit-i386-3.6.2-64/tmpwxirmnj7/mod.cpp
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-6-d4c01a09f65a> in <module>()
#      24         sku_planned = pm.Poisson(f'sku_planned_{i}', mu=sku_demand, observed=np.ceil(style_demand_planned * sku['sku_percent']))
#      25
# ---> 26     trace = pm.sample(n_samples, tune=n_burn, random_seed=42, progressbar=True)
#
# ~/anaconda3/lib/python3.6/site-packages/pymc3/sampling.py in sample(draws, step, init, n_init, start, trace, chain, njobs, tune, nuts_kwargs, step_kwargs, progressbar, model, random_seed, live_plot, discard_tuned_samples, live_plot_kwargs, **kwargs)
#     241         start_, step = init_nuts(init=init, njobs=njobs, n_init=n_init,
#     242                                  model=model, random_seed=random_seed,
# --> 243                                  progressbar=progressbar, **args)
#     244         if start is None:
#     245             start = start_
#
# ~/anaconda3/lib/python3.6/site-packages/pymc3/sampling.py in init_nuts(init, njobs, n_init, model, random_seed, progressbar, **kwargs)
#     600             callbacks=cb,
#     601             progressbar=progressbar,
# --> 602             obj_optimizer=pm.adagrad_window
#     603         )  # type: pm.MeanField
#     604         start = approx.sample(draws=njobs)
#
# ~/anaconda3/lib/python3.6/site-packages/pymc3/variational/inference.py in fit(n, local_rv, method, model, random_seed, start, inf_kwargs, **kwargs)
#     753                         'or Inference instance' %
#     754                         set(_select.keys()))
# --> 755     return inference.fit(n, **kwargs)
#
# ~/anaconda3/lib/python3.6/site-packages/pymc3/variational/inference.py in fit(self, n, score, callbacks, progressbar, **kwargs)
#     121             callbacks = []
#     122         score = self._maybe_score(score)
# --> 123         step_func = self.objective.step_function(score=score, **kwargs)
#     124         progress = tqdm.trange(n, disable=not progressbar)
#     125         if score:
#
# ~/anaconda3/lib/python3.6/site-packages/pymc3/memoize.py in memoizer(*args, **kwargs)
#      14
#      15         if key not in cache:
# ---> 16             cache[key] = obj(*args, **kwargs)
#      17
#      18         return cache[key]
#
# ~/anaconda3/lib/python3.6/site-packages/theano/configparser.py in res(*args, **kwargs)
#     115         def res(*args, **kwargs):
#     116             with self:
# --> 117                 return f(*args, **kwargs)
#     118         return res
#     119
#
# ~/anaconda3/lib/python3.6/site-packages/pymc3/variational/opvi.py in step_function(self, obj_n_mc, tf_n_mc, obj_optimizer, test_optimizer, more_obj_params, more_tf_params, more_updates, more_replacements, total_grad_norm_constraint, score, fn_kwargs)
#     259         if score:
#     260             step_fn = theano.function(
# --> 261                 [], updates.loss, updates=updates, **fn_kwargs)
#     262         else:
#     263             step_fn = theano.function([], None, updates=updates, **fn_kwargs)
#
# ~/anaconda3/lib/python3.6/site-packages/theano/compile/function.py in function(inputs, outputs, mode, updates, givens, no_default_updates, accept_inplace, name, rebuild_strict, allow_input_downcast, profile, on_unused_input)
#     324                    on_unused_input=on_unused_input,
#     325                    profile=profile,
# --> 326                    output_keys=output_keys)
#     327     # We need to add the flag check_aliased inputs if we have any mutable or
#     328     # borrowed used defined inputs
#
# ~/anaconda3/lib/python3.6/site-packages/theano/compile/pfunc.py in pfunc(params, outputs, mode, updates, givens, no_default_updates, accept_inplace, name, rebuild_strict, allow_input_downcast, profile, on_unused_input, output_keys)
#     484                          accept_inplace=accept_inplace, name=name,
#     485                          profile=profile, on_unused_input=on_unused_input,
# --> 486                          output_keys=output_keys)
#     487
#     488
#
# ~/anaconda3/lib/python3.6/site-packages/theano/compile/function_module.py in orig_function(inputs, outputs, mode, accept_inplace, name, profile, on_unused_input, output_keys)
#    1793                    on_unused_input=on_unused_input,
#    1794                    output_keys=output_keys).create(
# -> 1795             defaults)
#    1796
#    1797     t2 = time.time()
#
# ~/anaconda3/lib/python3.6/site-packages/theano/compile/function_module.py in create(self, input_storage, trustme, storage_map)
#    1659             theano.config.traceback.limit = theano.config.traceback.compile_limit
#    1660             _fn, _i, _o = self.linker.make_thunk(
# -> 1661                 input_storage=input_storage_lists, storage_map=storage_map)
#    1662         finally:
#    1663             theano.config.traceback.limit = limit_orig
#
# ~/anaconda3/lib/python3.6/site-packages/theano/gof/link.py in make_thunk(self, input_storage, output_storage, storage_map)
#     697         return self.make_all(input_storage=input_storage,
#     698                              output_storage=output_storage,
# --> 699                              storage_map=storage_map)[:3]
#     700
#     701     def make_all(self, input_storage, output_storage):
#
# ~/anaconda3/lib/python3.6/site-packages/theano/gof/vm.py in make_all(self, profiler, input_storage, output_storage, storage_map)
#    1045                                                  compute_map,
#    1046                                                  no_recycling,
# -> 1047                                                  impl=impl))
#    1048                 linker_make_thunk_time[node] = time.time() - thunk_start
#    1049                 if not hasattr(thunks[-1], 'lazy'):
#
# ~/anaconda3/lib/python3.6/site-packages/theano/gof/op.py in make_thunk(self, node, storage_map, compute_map, no_recycling, impl)
#     933             try:
#     934                 return self.make_c_thunk(node, storage_map, compute_map,
# --> 935                                          no_recycling)
#     936             except (NotImplementedError, utils.MethodNotDefined):
#     937                 # We requested the c code, so don't catch the error.
#
# ~/anaconda3/lib/python3.6/site-packages/theano/gof/op.py in make_c_thunk(self, node, storage_map, compute_map, no_recycling)
#     837         _logger.debug('Trying CLinker.make_thunk')
#     838         outputs = cl.make_thunk(input_storage=node_input_storage,
# --> 839                                 output_storage=node_output_storage)
#     840         fill_storage, node_input_filters, node_output_filters = outputs
#     841
#
# ~/anaconda3/lib/python3.6/site-packages/theano/gof/cc.py in make_thunk(self, input_storage, output_storage, storage_map, keep_lock)
#    1188         cthunk, in_storage, out_storage, error_storage = self.__compile__(
#    1189             input_storage, output_storage, storage_map,
# -> 1190             keep_lock=keep_lock)
#    1191
#    1192         res = _CThunk(cthunk, init_tasks, tasks, error_storage)
#
# ~/anaconda3/lib/python3.6/site-packages/theano/gof/cc.py in __compile__(self, input_storage, output_storage, storage_map, keep_lock)
#    1129                                     output_storage,
#    1130                                     storage_map,
# -> 1131                                     keep_lock=keep_lock)
#    1132         return (thunk,
#    1133                 [link.Container(input, storage) for input, storage in
#
# ~/anaconda3/lib/python3.6/site-packages/theano/gof/cc.py in cthunk_factory(self, error_storage, in_storage, out_storage, storage_map, keep_lock)
#    1584                 node.op.prepare_node(node, storage_map, None, 'c')
#    1585             module = get_module_cache().module_from_key(
# -> 1586                 key=key, lnk=self, keep_lock=keep_lock)
#    1587
#    1588         vars = self.inputs + self.outputs + self.orphans
#
# ~/anaconda3/lib/python3.6/site-packages/theano/gof/cmodule.py in module_from_key(self, key, lnk, keep_lock)
#    1157             try:
#    1158                 location = dlimport_workdir(self.dirname)
# -> 1159                 module = lnk.compile_cmodule(location)
#    1160                 name = module.__file__
#    1161                 assert name.startswith(location)
#
# ~/anaconda3/lib/python3.6/site-packages/theano/gof/cc.py in compile_cmodule(self, location)
#    1487                 lib_dirs=self.lib_dirs(),
#    1488                 libs=libs,
# -> 1489                 preargs=preargs)
#    1490         except Exception as e:
#    1491             e.args += (str(self.fgraph),)
#
# ~/anaconda3/lib/python3.6/site-packages/theano/gof/cmodule.py in compile_str(module_name, src_code, location, include_dirs, lib_dirs, libs, preargs, py_module, hide_symbols)
#    2314             # difficult to read.
#    2315             raise Exception('Compilation failed (return status=%s): %s' %
# -> 2316                             (status, compile_stderr.replace('\n', '. ')))
#    2317         elif config.cmodule.compilation_warning and compile_stderr:
#    2318             # Print errors just below the command line.
#
# Exception: ('The following error happened while compiling the node', Elemwise{Composite{scalar_identity((i0 - ((Switch(Identity((GE(i1, i2) * LE(i1, i3))), i4, i5) - ((i6 * scalar_softplus(i7)) + i8)) + (Switch(Identity((GE(i9, i2) * LE(i9, i3))), i4, i5) - ((i6 * scalar_softplus(i10)) + i11)) + (Switch(Identity((GE(i12, i2) * LE(i12, i3))), i4, i5) - ((i6 * scalar_softplus(i13)) + i14)) + (Switch(Identity((GE(i15, i2) * LE(i15, i3))), i4, i5) - ((i6 * scalar_softplus(i16)) + i17)) + (Switch(Identity((GE(i18, i2) * LE(i18, i3))), i4, i5) - ((i6 * scalar_softplus(i19)) + i20)) + (Switch(Identity((GE(i21, i2) * LE(i21, i3))), i4, i5) - ((i6 * scalar_softplus(i22)) + i23)) + (Switch(Identity((GE(i24, i2) * LE(i24, i3))), i4, i5) - ((i6 * scalar_softplus(i25)) + i26)) + (Switch(Identity((GE(i27, i2) * LE(i27, i3))), i4, i5) - ((i6 * scalar_softplus(i28)) + i29)) + (Switch(Identity((GE(i30, i2) * LE(i30, i3))), i4, i5) - ((i6 * scalar_softplus(i31)) + i32)) + (Switch(Identity((GE(i33, i2) * LE(i33, i3))), i4, i5) - ((i6 * scalar_softplus(i34)) + i35)) + (Switch(Identity((GE(i36, i2) * LE(i36, i3))), i4, i5) - ((i6 * scalar_softplus(i37)) + i38)) + (Switch(Identity((GE(i39, i2) * LE(i39, i3))), i4, i5) - ((i6 * scalar_softplus(i40)) + i41)) + (Switch(Identity((GE(i42, i2) * LE(i42, i3))), i4, i5) - ((i6 * scalar_softplus(i43)) + i44)) + (Switch(Identity((GE(i45, i2) * LE(i45, i3))), i4, i5) - ((i6 * scalar_softplus(i46)) + i47)) + (Switch(Identity((GE(i48, i2) * LE(i48, i3))), i4, i5) - ((i6 * scalar_softplus(i49)) + i50)) + (Switch(Identity((GE(i51, i2) * LE(i51, i3))), i4, i5) - ((i6 * scalar_softplus(i52)) + i53)) + (Switch(Identity((GE(i54, i2) * LE(i54, i3))), i4, i5) - ((i6 * scalar_softplus(i55)) + i56)) + (Switch(Identity((GE(i57, i2) * LE(i57, i3))), i4, i5) - ((i6 * scalar_softplus(i58)) + i59)) + (Switch(Identity((GE(i60, i2) * LE(i60, i3))), i4, i5) - ((i6 * scalar_softplus(i61)) + i62)) + (Switch(Identity((GE(i63, i2) * LE(i63, i3))), i4, i5) - ((i6 * scalar_softplus(i64)) + i65)) + (Switch(Identity((GE(i66, i2) * LE(i66, i3))), i4, i5) - ((i6 * scalar_softplus(i67)) + i68)) + (Switch(Identity((GE(i69, i2) * LE(i69, i3))), i4, i5) - ((i6 * scalar_softplus(i70)) + i71)) + (Switch(Identity((GE(i72, i2) * LE(i72, i3))), i4, i5) - ((i6 * scalar_softplus(i73)) + i74)) + (Switch(Identity((GE(i75, i2) * LE(i75, i3))), i4, i5) - ((i6 * scalar_softplus(i76)) + i77)) + (Switch(Identity((GE(i78, i2) * LE(i78, i3))), i4, i5) - ((i6 * scalar_softplus(i79)) + i80)) + (Switch(Identity((GE(i81, i2) * LE(i81, i3))), i4, i5) - ((i6 * scalar_softplus(i82)) + i83)) + (Switch(Identity((GE(i84, i2) * LE(i84, i3))), i4, i5) - ((i6 * scalar_softplus(i85)) + i86)) + (Switch(Identity((GE(i87, i2) * LE(i87, i3))), i4, i5) - ((i6 * scalar_softplus(i88)) + i89)) + (Switch(Identity((GE(i90, i2) * LE(i90, i3))), i4, i5) - ((i6 * scalar_softplus(i91)) + i92)) + (Switch(Identity((GE(i93, i2) * LE(i93, i3))), i4, i5) - ((i6 * scalar_softplus(i94)) + i95)) + (Switch(Identity((GE(i96, i2) * LE(i96, i3))), i4, i5) - ((i6 * scalar_softplus(i97)) + i98)) + (Switch(Identity((GE(i99, i2) * LE(i99, i3))), i4, i5) - ((i6 * scalar_softplus(i100)) + i101)) + (Switch(Identity((GE(i102, i2) * LE(i102, i3))), i4, i5) - ((i6 * scalar_softplus(i103)) + i104)) + (Switch(Identity((GE(i105, i2) * LE(i105, i3))), i4, i5) - ((i6 * scalar_softplus(i106)) + i107)) + (Switch(Identity((GE(i108, i2) * LE(i108, i3))), i4, i5) - ((i6 * scalar_softplus(i109)) + i110)) + (Switch(Identity((GE(i111, i2) * LE(i111, i3))), i4, i5) - ((i6 * scalar_softplus(i112)) + i113)) + (Switch(Identity((GE(i114, i2) * LE(i114, i3))), i4, i5) - ((i6 * scalar_softplus(i115)) + i116)) + (Switch(Identity((GE(i117, i2) * LE(i117, i3))), i4, i5) - ((i6 * scalar_softplus(i118)) + i119)) + (Switch(Identity((GE(i120, i2) * LE(i120, i3))), i4, i5) - ((i6 * scalar_softplus(i121)) + i122)) + (Switch(Identity((GE(i123, i2) * LE(i123, i3))), i4, i5) - ((i6 * scalar_softplus(i124)) + i125)) + (Switch(Identity((GE( ...
